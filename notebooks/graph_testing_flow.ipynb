# %% [markdown]
# <a href="https://colab.research.google.com/github/abergh18/marl-tsc/blob/zak_new/notebooks/graph_testing_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### env

# %%
import sys

IN_COLAB = 'google.colab' in sys.modules
COLAB = False

if IN_COLAB:
    print("Running inside Google Colab!")
    COLAB = True
else:
    print("Running in a local/different environment.")
# Out:
# Running inside Google Colab!

# %%
if not COLAB:
  # Uncomment these in a fresh notebook environment.
  # %pip install -r ../requirements.txt
  # %pip install -e ..

# %%
if COLAB:
  #GITHUB --> COLAB CLONE / env setup
  import os
  from google.colab import userdata

  # 1. Get your access token
  token = userdata.get('GH_TOKEN')

  # 2. Clone the repo if it's not already there
  repo_path = '/content/marl-tsc'
  if not os.path.exists(repo_path):
      # !git clone --branch zak_new --single-branch https://{token}@github.com/abergh18/marl-tsc.git

  # 3. CRUCIAL: Move to the root directory
  # This ensures that 'import models' or 'import utils' works correctly
  # %cd {repo_path}

  # 4. Install dependencies
  # !pip install -r requirements.txt
# Out:
# /content/marl-tsc
# Requirement already satisfied: pettingzoo==1.26.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: gymnasium==1.2.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.2.3)
# Requirement already satisfied: numpy<2.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Collecting traci==1.26.0 (from -r requirements.txt (line 4))
#   Using cached traci-1.26.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting sumolib==1.26.0 (from -r requirements.txt (line 5))
#   Using cached sumolib-1.26.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jupyter==1.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: matplotlib<3.11,>=3.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: supersuit==3.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: stable-baselines3==2.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.8.0)
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.11.0+cu128)
# Requirement already satisfied: torch-geometric==2.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.8.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (0.0.6)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (7.17.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (7.7.1)
# Requirement already satisfied: jupyterlab in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (4.6.1)
# Requirement already satisfied: tinyscaler>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from supersuit==3.10.0->-r requirements.txt (line 8)) (1.2.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.29.3)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.14.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.7.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0->-r requirements.txt (line 10)) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.11.0->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.24.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (6.5.7)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.11.0->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (5.9.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jupyter-builder>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2026.5.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (4.10.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (0.8.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (2.8.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.8.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2026.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.4.0)
# Using cached traci-1.26.0-py2.py3-none-any.whl (138 kB)
# Using cached sumolib-1.26.0-py2.py3-none-any.whl (233 kB)
# Installing collected packages: sumolib, traci
#   Attempting uninstall: sumolib
#     Found existing installation: sumolib 1.27.1
#     Uninstalling sumolib-1.27.1:
#       Successfully uninstalled sumolib-1.27.1
#   Attempting uninstall: traci
#     Found existing installation: traci 1.27.1
#     Uninstalling traci-1.27.1:
#       Successfully uninstalled traci-1.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libsumo 1.27.1 requires traci>=1.27.1, but you have traci 1.26.0 which is incompatible.
# Successfully installed sumolib-1.26.0 traci-1.26.0

# %%
if COLAB:
  # !pip install eclipse-sumo libsumo

  import os
  os.environ["SUMO_HOME"] = "/usr/local/lib/python3.12/dist-packages/sumo"
  os.environ["PATH"] += ":/usr/local/lib/python3.12/dist-packages/sumo/bin"
# Out:
# Requirement already satisfied: eclipse-sumo in /usr/local/lib/python3.12/dist-packages (1.27.1)
# Requirement already satisfied: libsumo in /usr/local/lib/python3.12/dist-packages (1.27.1)
# Requirement already satisfied: sumo-data>=1.27.1 in /usr/local/lib/python3.12/dist-packages (from eclipse-sumo) (1.27.1)
# Collecting traci>=1.27.1 (from libsumo)
#   Using cached traci-1.27.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting sumolib>=1.27.1 (from traci>=1.27.1->libsumo)
#   Using cached sumolib-1.27.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached traci-1.27.1-py2.py3-none-any.whl (138 kB)
# Using cached sumolib-1.27.1-py2.py3-none-any.whl (236 kB)
# Installing collected packages: sumolib, traci
#   Attempting uninstall: sumolib
#     Found existing installation: sumolib 1.26.0
#     Uninstalling sumolib-1.26.0:
#       Successfully uninstalled sumolib-1.26.0
#   Attempting uninstall: traci
#     Found existing installation: traci 1.26.0
#     Uninstalling traci-1.26.0:
#       Successfully uninstalled traci-1.26.0
# Successfully installed sumolib-1.27.1 traci-1.27.1

# %%
from pathlib import Path
import sys
#Had to remove '.parent' for colab specific version
PROJECT_ROOT = Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from pathlib import Path

import matplotlib.pyplot as plt

GREEN_PHASE_COUNT = None

def print_comparison_table(rows):
    columns = [
        "Policy",
        "Episodes",
        "Mean total reward",
        "Mean local queue",
        "Total completed steps",
        "Mean switches / episode",
    ]

    def format_value(value):
        if isinstance(value, float):
            return f"{value:.3f}"
        return str(value)

    widths = {column: len(column) for column in columns}
    for row in rows:
        for column in columns:
            widths[column] = max(widths[column], len(format_value(row.get(column, ""))))

    header = " | ".join(column.ljust(widths[column]) for column in columns)
    separator = "-+-".join("-" * widths[column] for column in columns)
    print(header)
    print(separator)
    for row in rows:
        print(" | ".join(format_value(row.get(column, "")).ljust(widths[column]) for column in columns))

# %%
from marl_tsc.simulation_generator import SimulationGenerator, DEFAULT_TRAFFIC_LIGHT_IDS
from marl_tsc.training import train_ppo, evaluate_policy, plot_training_histories
from marl_tsc.mappo import train_mappo
from marl_tsc.baselines import random_actions, fixed_time_actions

NOTEBOOK_DIR = Path.cwd().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent if (NOTEBOOK_DIR / "main_flow.ipynb").exists() else NOTEBOOK_DIR
if COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  OUTPUT_DIR = '/content/drive/MyDrive/Uni-Masters/Group Project/outputs'
else:
  OUTPUT_DIR = PROJECT_ROOT / "outputs"

traffic_light_ids = list(DEFAULT_TRAFFIC_LIGHT_IDS)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#! ls -la '/content/drive/MyDrive/Uni-Masters/Group Project/outputs'

# %%
EPISODE_STEPS = 600
SECONDS_PER_ACTION = 5
SIMULATION_DURATION = EPISODE_STEPS * SECONDS_PER_ACTION

# Keep vehicles entering slightly longer than the episode runs.
TRAFFIC_SPAWN_DURATION = int(SIMULATION_DURATION * 1.20)

EVALUATION_EPISODES = 3
TOTAL_TIMESTEPS = 200_000
MIN_GREEN_SECONDS = 10
SWITCH_PENALTY = 0.00

generator = SimulationGenerator(
    output_dir=OUTPUT_DIR,
    grid_number=4,
    lane_number=2,
    traffic_light_ids=traffic_light_ids,
    trip_begin=0,
    trip_end=TRAFFIC_SPAWN_DURATION,
    trip_period=2,
    seed=42,
)

paths = generator.generate_all()
print(f"Generated SUMO config: {paths.config_file}")
print(f"Simulation horizon: {SIMULATION_DURATION}s")
print(f"Traffic spawn duration: {TRAFFIC_SPAWN_DURATION}s")
print("Traffic-light agents:", traffic_light_ids)
# Out:
# Generated SUMO config: /content/drive/MyDrive/Uni-Masters/Group Project/outputs/config.sumocfg
# Simulation horizon: 3000s
# Traffic spawn duration: 3600s
# Traffic-light agents: ['B1', 'B2', 'C1', 'C2']

# %% [markdown]
# ## 2. Run the simple baselines
#
# Random and fixed-time are useful sanity checks before training. They use the same environment and the same evaluation seeds as the learned policies.

# %%
# ==========================================
# 1. RANDOM BASELINE EVALUATION
# ==========================================
random_result = evaluate_policy(
    config_file=paths.config_file,
    traffic_light_ids=traffic_light_ids,             # Match MAPPO: TODO:Extract dynamically from the net file
    policy=random_actions,
    episodes=1,#EVALUATION_EPISODES,       # Use 10 episodes to match MAPPO evaluation
    max_steps=600, #EPISODE_STEPS,            # FIX: Must be 600 steps, not 3000 duration
    seed=42,
    env_kwargs={
        "green_phase_count": 4,
        "min_green_seconds": MIN_GREEN_SECONDS,
        "seconds_per_action": SECONDS_PER_ACTION,
        #"max_steps": 600,     # Pass to ensure internal alignment
    },
)

# ==========================================
# 2. FIXED-TIME BASELINE EVALUATION
# ==========================================
fixed_time_result = evaluate_policy(
    config_file=paths.config_file,
    traffic_light_ids=traffic_light_ids,             # Match MAPPO: TODO: Extract dynamically from the net file
    policy=fixed_time_actions,
    episodes= 1,#EVALUATION_EPISODES,       # Use 10 episodes to match MAPPO evaluation
    max_steps= 600, #EPISODE_STEPS,            # FIX: Must be 600 steps, not 3000 duration
    seed=42,
    env_kwargs={
        "green_phase_count": 4,
        "min_green_seconds": MIN_GREEN_SECONDS,
        "seconds_per_action": SECONDS_PER_ACTION,
        #"max_steps": 600,     # Pass to ensure internal alignment
    },
)
# Out:
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 0 ACT 0 BUF 0)
#  Retrying in 1 seconds
# Step #3000.00 (0ms ?*RT. ?UPS, TraCI: 7ms, vehicles TOT 1500 ACT 39 BUF 0)
# Finished Evaluation Episode 1/1 - Total Reward: -133.12
#  Retrying in 1 seconds
# Step #0.00 (0ms ?*RT. ?UPS, TraCI: 2ms, vehicles TOT 0 ACT 0 BUF 0)
#  Retrying in 1 seconds
# Step #3000.00 (3ms ~= 333.33*RT, ~184000.00UPS, TraCI: 8ms, vehicles TOT 1160 ACT 552 BUF
# Finished Evaluation Episode 1/1 - Total Reward: -1335.24

# %%
baseline_rows = [
    {
        "Policy": "Random",
        "Episodes": random_result["episodes"],
        "Mean total reward": random_result["mean_total_reward"],
        "Mean local queue": random_result["mean_local_queue"],
        "Total completed steps": random_result["total_completed_steps"],
        "Mean switches / episode": random_result["mean_switches_per_episode"],
    },
    {
        "Policy": "Fixed-Time",
        "Episodes": fixed_time_result["episodes"],
        "Mean total reward": fixed_time_result["mean_total_reward"],
        "Mean local queue": fixed_time_result["mean_local_queue"],
        "Total completed steps": fixed_time_result["total_completed_steps"],
        "Mean switches / episode": fixed_time_result["mean_switches_per_episode"],
    },
]
print_comparison_table(baseline_rows)
# Out:
# Policy     | Episodes | Mean total reward | Mean local queue | Total completed steps | Mean switches / episode
# -----------+----------+-------------------+------------------+-----------------------+------------------------
# Random     | 1        | -133.120          | 0.512            | 600                   | 1027.000
# Fixed-Time | 1        | -1335.235         | 5.514            | 600                   | 1196.000

# %% [markdown]
# ## Traci Escape Hatch

# %%
on = True
if on:
    # Stop Traci processes if not already stopped, to prevent connection issues in subsequent runs
    import sys

    # 1. Force clear TraCI's internal connection registries
    try:
        import traci
        traci.switch("default")
        traci.close()
    except Exception:
        pass

    try:
        # Completely purge the connection dictionary tracking connections
        import traci.main
        traci.main._connections.clear()
        print("Purged TraCI connections dictionary.")
    except Exception:
        pass

    # 2. Reset the module completely out of Python sys memory
    if 'traci' in sys.modules:
        del sys.modules['traci']
        print("Flushed TraCI module from Python runtime memory.")

    # 3. Re-import fresh
    import traci
    print("TraCI state successfully reset!")
# Out:
# Flushed TraCI module from Python runtime memory.
# TraCI state successfully reset!

# %% [markdown]
# ## Graph Stuff

# %%
paths = generator.generate_all()

# %% [markdown]
# ### viz

# %%
from marl_tsc.graph_based.graph_builder import GraphBuilder

builder = GraphBuilder(paths.network_file)

topology = builder.build()
print("Topology output:")
print("List of Nodes")
print(topology.agent_ids)
print("Edge Index:Columns Represent source --> Target")
print(topology.edge_index)
# Out:
# Topology output:
# List of Nodes
# ['B1', 'B2', 'C1', 'C2']
# Edge Index:Columns Represent source --> Target
# tensor([[0, 3, 2, 2, 0, 1, 3, 1],
#         [1, 1, 0, 3, 2, 0, 2, 3]])

# %%
tls = next(iter(builder.net.getTrafficLights()))

connections = tls.getConnections()

print(connections[0])

incoming_lane = connections[0][0]
outgoing_lane = connections[0][1]

print(type(incoming_lane))
print(type(outgoing_lane))

print(sorted(
    attr
    for attr in dir(incoming_lane)
    if not attr.startswith("_")
)[:50])
# Out:
# [<sumolib.net.lane.Lane object at 0x7c723106c230>, <sumolib.net.lane.Lane object at 0x7c723106d7c0>, 15]
# <class 'sumolib.net.lane.Lane'>
# <class 'sumolib.net.lane.Lane'>
# ['addOutgoing', 'allows', 'getBoundingBox', 'getClosestLanePosAndDist', 'getConnection', 'getEdge', 'getID', 'getIncoming', 'getIncomingConnections', 'getIndex', 'getLength', 'getNeigh', 'getOutgoing', 'getOutgoingEdges', 'getOutgoingLanes', 'getParam', 'getParams', 'getPermissions', 'getShape', 'getShape3D', 'getSpeed', 'getWidth', 'interpretOffset', 'isAccelerationLane', 'isNormal', 'setNeigh', 'setParam', 'setPermissions', 'setShape']

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()

for agent in topology.agent_ids:
    G.add_node(agent)

for src, dst in topology.edge_index.t().tolist():
    G.add_edge(
        topology.agent_ids[src],
        topology.agent_ids[dst]
    )

plt.figure(figsize=(6, 6))

nx.draw(
    G,
    with_labels=True,
    node_size=2000,
)

plt.show()

# %% [markdown]
# ### Graph ctde

# %%
from marl_tsc.graph_based.train_graph_ctde import (
    train_graph_ctde,
)

model, history, model_path = (
    train_graph_ctde(
        config_file=paths.config_file,
        network_file=paths.network_file,
        traffic_light_ids=traffic_light_ids,
        output_dir=OUTPUT_DIR,
        total_timesteps=200_000,
        rollout_steps=256,
        actor_learning_rate=2e-4,#2e-4
        critic_learning_rate=5e-4,#5e-4
        entropy_coef=5e-3,#5e-3
        env_kwargs={
            "green_phase_count": GREEN_PHASE_COUNT,
            "min_green_seconds": MIN_GREEN_SECONDS,
            "seconds_per_action": SECONDS_PER_ACTION,
            "switch_penalty": SWITCH_PENALTY,
            "global_metric_interval": 10,
        },
    )
)

print(type(model))
print(len(history))
print(model_path)
print(history[-1])
# Out:
# Streaming output truncated to the last 5000 lines.
# entropy=5.5435 | logit_gap=0.0620 | max_prob=0.2583
# value=-7.217 target=-7.932
# entropy=5.5421 | logit_gap=0.0999 | max_prob=0.2638
# value=-8.246 target=-7.893
# entropy=5.5446 | logit_gap=0.0401 | max_prob=0.2551
# value=-8.098 target=-7.858
# entropy=5.5381 | logit_gap=0.1493 | max_prob=0.2749
# value=-7.652 target=-7.859
# entropy=5.5430 | logit_gap=0.0902 | max_prob=0.2598
# value=-7.353 target=-7.897
# entropy=5.5442 | logit_gap=0.0578 | max_prob=0.2553
# value=-7.470 target=-7.932
# entropy=5.5448 | logit_gap=0.0343 | max_prob=0.2527
# value=-7.344 target=-7.965
# entropy=5.5330 | logit_gap=0.1901 | max_prob=0.2810
# value=-7.318 target=-8.009
# entropy=5.5378 | logit_gap=0.1545 | max_prob=0.2686
# value=-7.272 target=-8.056
# entropy=5.5441 | logit_gap=0.0576 | max_prob=0.2571
# value=-7.989 target=-8.052
# entropy=5.5442 | logit_gap=0.0592 | max_prob=0.2588
# value=-7.506 target=-8.079
# entropy=5.5416 | logit_gap=0.1021 | max_prob=0.2673
# value=-7.474 target=-8.104
# entropy=5.5275 | logit_gap=0.2259 | max_prob=0.2865
# value=-7.486 target=-8.119
# entropy=5.5426 | logit_gap=0.0794 | max_prob=0.2597
# value=-8.245 target=-8.087
# entropy=5.5438 | logit_gap=0.0742 | max_prob=0.2601
# value=-7.449 target=-8.153
# entropy=5.5444 | logit_gap=0.0524 | max_prob=0.2551
# value=-6.935 target=-8.259
# entropy=5.5400 | logit_gap=0.1352 | max_prob=0.2698
# value=-7.357 target=-8.317
# entropy=5.5450 | logit_gap=0.0254 | max_prob=0.2537
# value=-7.646 target=-8.353
# entropy=5.5445 | logit_gap=0.0505 | max_prob=0.2573
# value=-7.501 target=-8.377
# entropy=5.5416 | logit_gap=0.1062 | max_prob=0.2667
# value=-7.483 target=-8.394
# entropy=5.5450 | logit_gap=0.0246 | max_prob=0.2527
# value=-8.085 target=-8.356
# entropy=5.5441 | logit_gap=0.0580 | max_prob=0.2563
# value=-7.590 target=-8.347
# entropy=5.5435 | logit_gap=0.0743 | max_prob=0.2617
# value=-8.002 target=-8.308
# entropy=5.5412 | logit_gap=0.1112 | max_prob=0.2678
# value=-7.645 target=-8.279
# entropy=5.5436 | logit_gap=0.0694 | max_prob=0.2551
# value=-7.961 target=-8.217
# entropy=5.5341 | logit_gap=0.1971 | max_prob=0.2791
# value=-7.320 target=-8.208
# entropy=5.5440 | logit_gap=0.0629 | max_prob=0.2558
# value=-7.738 target=-8.211
# entropy=5.5449 | logit_gap=0.0278 | max_prob=0.2533
# value=-7.978 target=-8.190
# entropy=5.5446 | logit_gap=0.0401 | max_prob=0.2570
# value=-7.638 target=-8.160
# entropy=5.5446 | logit_gap=0.0451 | max_prob=0.2553
# value=-7.454 target=-8.106
# entropy=5.5354 | logit_gap=0.1688 | max_prob=0.2797
# value=-7.920 target=-8.019
# entropy=5.5393 | logit_gap=0.1365 | max_prob=0.2722
# value=-7.563 target=-7.985
# entropy=5.5440 | logit_gap=0.0689 | max_prob=0.2580
# value=-7.706 target=-7.933
# entropy=5.5384 | logit_gap=0.1562 | max_prob=0.2665
# value=-7.387 target=-7.892
# entropy=5.5421 | logit_gap=0.1075 | max_prob=0.2641
# value=-7.834 target=-7.824
# entropy=5.5429 | logit_gap=0.0891 | max_prob=0.2631
# value=-7.912 target=-7.754
# entropy=5.5447 | logit_gap=0.0370 | max_prob=0.2531
# value=-7.688 target=-7.683
# entropy=5.5443 | logit_gap=0.0531 | max_prob=0.2585
# value=-7.637 target=-7.618
# entropy=5.5443 | logit_gap=0.0566 | max_prob=0.2562
# value=-7.684 target=-7.598
# entropy=5.5441 | logit_gap=0.0595 | max_prob=0.2561
# value=-7.531 target=-7.602
# entropy=5.5411 | logit_gap=0.1101 | max_prob=0.2687
# value=-7.340 target=-7.638
# entropy=5.5446 | logit_gap=0.0410 | max_prob=0.2545
# value=-6.994 target=-7.676
# entropy=5.5387 | logit_gap=0.1389 | max_prob=0.2727
# value=-7.400 target=-7.679
# entropy=5.5360 | logit_gap=0.1760 | max_prob=0.2752
# value=-7.337 target=-7.681
# entropy=5.5446 | logit_gap=0.0409 | max_prob=0.2555
# value=-6.924 target=-7.709
# entropy=5.5448 | logit_gap=0.0357 | max_prob=0.2537
# value=-7.284 target=-7.713
# entropy=5.5406 | logit_gap=0.1292 | max_prob=0.2677
# value=-7.385 target=-7.705
# entropy=5.5411 | logit_gap=0.1159 | max_prob=0.2626
# value=-7.444 target=-7.700
# entropy=5.5442 | logit_gap=0.0566 | max_prob=0.2548
# value=-7.393 target=-7.695
# entropy=5.5437 | logit_gap=0.0755 | max_prob=0.2585
# value=-7.536 target=-7.662
# entropy=5.5436 | logit_gap=0.0782 | max_prob=0.2593
# value=-7.521 target=-7.666
# entropy=5.5448 | logit_gap=0.0370 | max_prob=0.2537
# value=-7.428 target=-7.681
# entropy=5.5375 | logit_gap=0.1577 | max_prob=0.2749
# value=-7.689 target=-7.663
# entropy=5.5418 | logit_gap=0.1058 | max_prob=0.2629
# value=-7.622 target=-7.646
# entropy=5.5418 | logit_gap=0.1035 | max_prob=0.2614
# value=-7.866 target=-7.596
# entropy=5.5445 | logit_gap=0.0481 | max_prob=0.2567
# value=-8.238 target=-7.540
# entropy=5.5437 | logit_gap=0.0747 | max_prob=0.2592
# value=-7.535 target=-7.567
# entropy=5.5448 | logit_gap=0.0335 | max_prob=0.2539
# value=-7.528 target=-7.585
# entropy=5.5431 | logit_gap=0.0892 | max_prob=0.2617
# value=-7.371 target=-7.632
# entropy=5.5444 | logit_gap=0.0519 | max_prob=0.2553
# value=-7.622 target=-7.639
# entropy=5.5419 | logit_gap=0.0974 | max_prob=0.2663
# value=-7.467 target=-7.669
# entropy=5.5446 | logit_gap=0.0405 | max_prob=0.2543
# value=-7.016 target=-7.713
# entropy=5.5359 | logit_gap=0.1768 | max_prob=0.2726
# value=-7.374 target=-7.728
# entropy=5.5436 | logit_gap=0.0724 | max_prob=0.2562
# value=-7.773 target=-7.712
# entropy=5.5449 | logit_gap=0.0298 | max_prob=0.2533
# value=-7.256 target=-7.714
# entropy=5.5334 | logit_gap=0.1816 | max_prob=0.2778
# value=-7.308 target=-7.714
# entropy=5.5414 | logit_gap=0.1026 | max_prob=0.2617
# value=-8.058 target=-7.669
# entropy=5.5443 | logit_gap=0.0495 | max_prob=0.2560
# value=-7.513 target=-7.647
# entropy=5.5445 | logit_gap=0.0468 | max_prob=0.2546
# value=-8.101 target=-7.582
# entropy=5.5451 | logit_gap=0.0137 | max_prob=0.2518
# value=-7.591 target=-7.529
# entropy=5.5442 | logit_gap=0.0562 | max_prob=0.2572
# value=-7.683 target=-7.484
# entropy=5.5448 | logit_gap=0.0351 | max_prob=0.2540
# value=-7.339 target=-7.449
# entropy=5.5450 | logit_gap=0.0255 | max_prob=0.2535
# value=-7.757 target=-7.395
# entropy=5.5230 | logit_gap=0.2554 | max_prob=0.2934
# value=-7.326 target=-7.368
# entropy=5.5284 | logit_gap=0.2279 | max_prob=0.2820
# value=-7.237 target=-7.363
# entropy=5.5405 | logit_gap=0.1138 | max_prob=0.2645
# value=-8.064 target=-7.295
# entropy=5.5439 | logit_gap=0.0626 | max_prob=0.2548
# value=-7.410 target=-7.258
# entropy=5.5378 | logit_gap=0.1553 | max_prob=0.2710
# value=-7.600 target=-7.200
# entropy=5.5442 | logit_gap=0.0594 | max_prob=0.2580
# value=-7.603 target=-7.144
# entropy=5.5432 | logit_gap=0.0854 | max_prob=0.2584
# value=-7.455 target=-7.092
# entropy=5.5441 | logit_gap=0.0605 | max_prob=0.2554
# value=-7.248 target=-7.058
# entropy=5.5396 | logit_gap=0.1288 | max_prob=0.2715
# value=-7.216 target=-7.048
# entropy=5.5395 | logit_gap=0.1308 | max_prob=0.2713
# value=-7.060 target=-7.055
# entropy=5.5416 | logit_gap=0.1049 | max_prob=0.2635
# value=-7.292 target=-7.046
# entropy=5.5437 | logit_gap=0.0672 | max_prob=0.2553
# value=-7.373 target=-7.011
# entropy=5.5444 | logit_gap=0.0504 | max_prob=0.2545
# value=-7.335 target=-6.959
# critic_epoch=5 loss=0.4549 grad=5.2328
#
# encoder_grad : 2.2087
# actor_grad   : 3.2205
# critic_grad  : 5.2328
# ExplainedVar : -0.020
# Value mean   : -7.480
# Value std    : 0.099
# Return mean  : -7.788
# Return std   : 0.570
# TD mean      : 0.531
# TD max       : 2.682
#
#
# ======================================================================
# Reward      : -0.0954
# Actor Loss  : -0.0140
# Critic Loss : 0.4549
# Entropy     : 5.5416
# ExplainedVar: -0.020
# TD mean/max : 0.531 / 2.682
# ======================================================================
#
#  Retrying in 1 seconds
# ValueNorm mean=-7.550 std=1.370
# ADV: mean=0.0000 std=1.0000 min=-1.8471 max=4.0977
# emb_mean=0.0609 emb_std=0.0674
# first_node_emb: [0.         0.19593963 0.1724919  0.06400354 0.        ]
# entropy=5.5437 | logit_gap=0.0721 | max_prob=0.2588
# Counter({3: 259, 2: 247, 0: 245, 1: 221})
# value=-7.291 target=-8.135
# entropy=5.5445 | logit_gap=0.0483 | max_prob=0.2557
# value=-7.964 target=-8.156
# entropy=5.5372 | logit_gap=0.1576 | max_prob=0.2755
# value=-7.866 target=-8.189
# entropy=5.5262 | logit_gap=0.2374 | max_prob=0.2885
# value=-7.872 target=-8.229
# entropy=5.5413 | logit_gap=0.1146 | max_prob=0.2620
# value=-8.042 target=-8.241
# entropy=5.5419 | logit_gap=0.1051 | max_prob=0.2628
# value=-8.634 target=-8.223
# entropy=5.5435 | logit_gap=0.0781 | max_prob=0.2576
# value=-7.701 target=-8.264
# entropy=5.5442 | logit_gap=0.0564 | max_prob=0.2551
# value=-7.732 target=-8.300
# entropy=5.5444 | logit_gap=0.0534 | max_prob=0.2559
# value=-8.156 target=-8.297
# entropy=5.5442 | logit_gap=0.0568 | max_prob=0.2555
# value=-7.753 target=-8.313
# entropy=5.5442 | logit_gap=0.0568 | max_prob=0.2563
# value=-7.634 target=-8.342
# entropy=5.5447 | logit_gap=0.0341 | max_prob=0.2545
# value=-7.430 target=-8.364
# entropy=5.5449 | logit_gap=0.0321 | max_prob=0.2547
# value=-8.084 target=-8.369
# entropy=5.5245 | logit_gap=0.2441 | max_prob=0.2926
# value=-7.845 target=-8.403
# entropy=5.5408 | logit_gap=0.1210 | max_prob=0.2639
# value=-7.851 target=-8.423
# entropy=5.5422 | logit_gap=0.1060 | max_prob=0.2621
# value=-8.280 target=-8.406
# entropy=5.5438 | logit_gap=0.0619 | max_prob=0.2565
# value=-7.827 target=-8.401
# entropy=5.5323 | logit_gap=0.2001 | max_prob=0.2819
# value=-8.126 target=-8.377
# entropy=5.5380 | logit_gap=0.1528 | max_prob=0.2663
# value=-8.242 target=-8.338
# entropy=5.5443 | logit_gap=0.0533 | max_prob=0.2543
# value=-7.920 target=-8.310
# entropy=5.5447 | logit_gap=0.0377 | max_prob=0.2529
# value=-8.026 target=-8.270
# entropy=5.5441 | logit_gap=0.0500 | max_prob=0.2561
# value=-7.481 target=-8.267
# entropy=5.5447 | logit_gap=0.0375 | max_prob=0.2530
# value=-7.612 target=-8.275
# entropy=5.5447 | logit_gap=0.0398 | max_prob=0.2544
# value=-7.640 target=-8.319
# entropy=5.5449 | logit_gap=0.0314 | max_prob=0.2528
# value=-7.730 target=-8.362
# entropy=5.5442 | logit_gap=0.0575 | max_prob=0.2554
# value=-7.825 target=-8.391
# entropy=5.5444 | logit_gap=0.0494 | max_prob=0.2548
# value=-8.070 target=-8.393
# entropy=5.5358 | logit_gap=0.1686 | max_prob=0.2786
# value=-7.884 target=-8.398
# entropy=5.5429 | logit_gap=0.0955 | max_prob=0.2609
# value=-7.968 target=-8.435
# entropy=5.5446 | logit_gap=0.0355 | max_prob=0.2542
# value=-7.531 target=-8.493
# entropy=5.5446 | logit_gap=0.0415 | max_prob=0.2533
# value=-7.906 target=-8.532
# entropy=5.5404 | logit_gap=0.1250 | max_prob=0.2696
# value=-8.100 target=-8.544
# entropy=5.5445 | logit_gap=0.0514 | max_prob=0.2560
# value=-8.739 target=-8.502
# entropy=5.5440 | logit_gap=0.0579 | max_prob=0.2573
# value=-7.151 target=-8.582
# entropy=5.5415 | logit_gap=0.1087 | max_prob=0.2618
# value=-8.252 target=-8.605
# entropy=5.5219 | logit_gap=0.2772 | max_prob=0.2944
# value=-7.639 target=-8.694
# entropy=5.5419 | logit_gap=0.0869 | max_prob=0.2605
# value=-8.237 target=-8.718
# entropy=5.5420 | logit_gap=0.1050 | max_prob=0.2619
# value=-8.169 target=-8.741
# entropy=5.5443 | logit_gap=0.0533 | max_prob=0.2548
# value=-7.982 target=-8.765
# entropy=5.5450 | logit_gap=0.0276 | max_prob=0.2538
# value=-8.478 target=-8.770
# entropy=5.5450 | logit_gap=0.0270 | max_prob=0.2528
# value=-7.864 target=-8.807
# entropy=5.5263 | logit_gap=0.2475 | max_prob=0.2875
# value=-8.080 target=-8.811
# entropy=5.5439 | logit_gap=0.0622 | max_prob=0.2571
# value=-8.706 target=-8.764
# entropy=5.5437 | logit_gap=0.0755 | max_prob=0.2595
# value=-8.546 target=-8.723
# entropy=5.5411 | logit_gap=0.1204 | max_prob=0.2645
# value=-8.139 target=-8.718
# entropy=5.5369 | logit_gap=0.1711 | max_prob=0.2712
# value=-8.307 target=-8.689
# entropy=5.5427 | logit_gap=0.0821 | max_prob=0.2605
# value=-8.103 target=-8.674
# entropy=5.5447 | logit_gap=0.0358 | max_prob=0.2534
# value=-8.145 target=-8.669
# entropy=5.5439 | logit_gap=0.0670 | max_prob=0.2601
# value=-7.806 target=-8.666
# entropy=5.5243 | logit_gap=0.2538 | max_prob=0.2918
# value=-8.045 target=-8.642
# entropy=5.5426 | logit_gap=0.0880 | max_prob=0.2601
# value=-8.363 target=-8.579
# entropy=5.5446 | logit_gap=0.0428 | max_prob=0.2549
# value=-7.782 target=-8.608
# entropy=5.5451 | logit_gap=0.0188 | max_prob=0.2523
# value=-7.986 target=-8.642
# entropy=5.5400 | logit_gap=0.1238 | max_prob=0.2710
# value=-8.317 target=-8.647
# entropy=5.5360 | logit_gap=0.1797 | max_prob=0.2747
# value=-7.757 target=-8.698
# entropy=5.5423 | logit_gap=0.0907 | max_prob=0.2614
# value=-8.689 target=-8.704
# entropy=5.5442 | logit_gap=0.0564 | max_prob=0.2579
# value=-8.312 target=-8.734
# entropy=5.5330 | logit_gap=0.1946 | max_prob=0.2822
# value=-7.919 target=-8.756
# entropy=5.5427 | logit_gap=0.0838 | max_prob=0.2593
# value=-7.792 target=-8.769
# entropy=5.5447 | logit_gap=0.0391 | max_prob=0.2551
# value=-9.169 target=-8.693
# entropy=5.5407 | logit_gap=0.1259 | max_prob=0.2682
# value=-8.262 target=-8.707
# entropy=5.5445 | logit_gap=0.0493 | max_prob=0.2551
# value=-8.519 target=-8.714
# entropy=5.5360 | logit_gap=0.1771 | max_prob=0.2746
# value=-8.119 target=-8.726
# entropy=5.5441 | logit_gap=0.0594 | max_prob=0.2555
# value=-8.015 target=-8.771
# entropy=5.5446 | logit_gap=0.0431 | max_prob=0.2552
# value=-7.462 target=-8.840
# entropy=5.5410 | logit_gap=0.1145 | max_prob=0.2685
# value=-7.964 target=-8.869
# entropy=5.5434 | logit_gap=0.0756 | max_prob=0.2559
# value=-8.304 target=-8.868
# entropy=5.5419 | logit_gap=0.1017 | max_prob=0.2659
# value=-8.101 target=-8.880
# entropy=5.5448 | logit_gap=0.0359 | max_prob=0.2551
# value=-8.503 target=-8.843
# entropy=5.5430 | logit_gap=0.0844 | max_prob=0.2620
# value=-8.051 target=-8.848
# entropy=5.5436 | logit_gap=0.0710 | max_prob=0.2558
# value=-8.467 target=-8.811
# entropy=5.5402 | logit_gap=0.1343 | max_prob=0.2674
# value=-8.189 target=-8.786
# entropy=5.5392 | logit_gap=0.1381 | max_prob=0.2708
# value=-8.167 target=-8.758
# entropy=5.5435 | logit_gap=0.0808 | max_prob=0.2600
# value=-8.410 target=-8.715
# entropy=5.5449 | logit_gap=0.0301 | max_prob=0.2540
# value=-8.726 target=-8.650
# entropy=5.5414 | logit_gap=0.1125 | max_prob=0.2671
# value=-8.368 target=-8.600
# entropy=5.5360 | logit_gap=0.1815 | max_prob=0.2739
# value=-8.088 target=-8.562
# entropy=5.5430 | logit_gap=0.0803 | max_prob=0.2614
# value=-9.106 target=-8.454
# entropy=5.5450 | logit_gap=0.0234 | max_prob=0.2529
# value=-8.173 target=-8.399
# entropy=5.5446 | logit_gap=0.0424 | max_prob=0.2553
# value=-8.290 target=-8.338
# entropy=5.5314 | logit_gap=0.2010 | max_prob=0.2844
# value=-7.802 target=-8.377
# entropy=5.5369 | logit_gap=0.1660 | max_prob=0.2684
# value=-7.831 target=-8.421
# entropy=5.5420 | logit_gap=0.1031 | max_prob=0.2628
# value=-8.519 target=-8.412
# entropy=5.5434 | logit_gap=0.0820 | max_prob=0.2590
# value=-8.493 target=-8.388
# entropy=5.5447 | logit_gap=0.0399 | max_prob=0.2555
# value=-8.903 target=-8.323
# entropy=5.5447 | logit_gap=0.0379 | max_prob=0.2533
# value=-8.287 target=-8.280
# entropy=5.5431 | logit_gap=0.0801 | max_prob=0.2602
# value=-8.970 target=-8.207
# entropy=5.5446 | logit_gap=0.0443 | max_prob=0.2540
# value=-8.456 target=-8.156
# entropy=5.5445 | logit_gap=0.0486 | max_prob=0.2557
# value=-8.160 target=-8.129
# entropy=5.5450 | logit_gap=0.0267 | max_prob=0.2531
# value=-8.071 target=-8.114
# entropy=5.5328 | logit_gap=0.2062 | max_prob=0.2805
# value=-7.866 target=-8.097
# entropy=5.5389 | logit_gap=0.1363 | max_prob=0.2662
# value=-7.982 target=-8.072
# entropy=5.5425 | logit_gap=0.0868 | max_prob=0.2620
# value=-8.581 target=-8.035
# entropy=5.5265 | logit_gap=0.2397 | max_prob=0.2866
# value=-7.944 target=-8.046
# entropy=5.5410 | logit_gap=0.1024 | max_prob=0.2636
# value=-7.907 target=-8.054
# entropy=5.5424 | logit_gap=0.0981 | max_prob=0.2609
# value=-8.111 target=-8.038
# entropy=5.5445 | logit_gap=0.0438 | max_prob=0.2560
# value=-8.018 target=-8.053
# entropy=5.5447 | logit_gap=0.0386 | max_prob=0.2559
# value=-7.713 target=-8.087
# entropy=5.5404 | logit_gap=0.1269 | max_prob=0.2676
# value=-7.870 target=-8.102
# entropy=5.5441 | logit_gap=0.0579 | max_prob=0.2552
# value=-7.817 target=-8.118
# entropy=5.5446 | logit_gap=0.0423 | max_prob=0.2539
# value=-7.729 target=-8.127
# entropy=5.5440 | logit_gap=0.0660 | max_prob=0.2582
# value=-7.685 target=-8.151
# entropy=5.5447 | logit_gap=0.0375 | max_prob=0.2533
# value=-7.969 target=-8.154
# entropy=5.5445 | logit_gap=0.0449 | max_prob=0.2560
# value=-7.757 target=-8.142
# entropy=5.5432 | logit_gap=0.0826 | max_prob=0.2620
# value=-8.293 target=-8.112
# entropy=5.5367 | logit_gap=0.1766 | max_prob=0.2737
# value=-7.817 target=-8.107
# entropy=5.5436 | logit_gap=0.0723 | max_prob=0.2560
# value=-7.967 target=-8.135
# entropy=5.5438 | logit_gap=0.0682 | max_prob=0.2574
# value=-8.007 target=-8.159
# entropy=5.5434 | logit_gap=0.0768 | max_prob=0.2568
# value=-7.793 target=-8.174
# entropy=5.5437 | logit_gap=0.0699 | max_prob=0.2578
# value=-8.584 target=-8.125
# entropy=5.5432 | logit_gap=0.0848 | max_prob=0.2597
# value=-7.815 target=-8.135
# entropy=5.5443 | logit_gap=0.0510 | max_prob=0.2548
# value=-8.290 target=-8.118
# entropy=5.5436 | logit_gap=0.0721 | max_prob=0.2584
# value=-7.871 target=-8.148
# entropy=5.5446 | logit_gap=0.0379 | max_prob=0.2546
# value=-7.537 target=-8.182
# entropy=5.5426 | logit_gap=0.0802 | max_prob=0.2600
# value=-7.676 target=-8.205
# entropy=5.5363 | logit_gap=0.1708 | max_prob=0.2681
# value=-7.933 target=-8.211
# entropy=5.5436 | logit_gap=0.0734 | max_prob=0.2564
# value=-8.049 target=-8.205
# entropy=5.5436 | logit_gap=0.0697 | max_prob=0.2567
# value=-8.043 target=-8.190
# entropy=5.5431 | logit_gap=0.0707 | max_prob=0.2588
# value=-7.950 target=-8.167
# entropy=5.5442 | logit_gap=0.0493 | max_prob=0.2560
# value=-8.134 target=-8.147
# entropy=5.5320 | logit_gap=0.1990 | max_prob=0.2837
# value=-7.756 target=-8.190
# entropy=5.5368 | logit_gap=0.1650 | max_prob=0.2676
# value=-7.804 target=-8.231
# entropy=5.5415 | logit_gap=0.1058 | max_prob=0.2635
# value=-8.492 target=-8.206
# entropy=5.5440 | logit_gap=0.0617 | max_prob=0.2551
# value=-7.880 target=-8.218
# entropy=5.5449 | logit_gap=0.0335 | max_prob=0.2545
# value=-8.149 target=-8.210
# entropy=5.5251 | logit_gap=0.2439 | max_prob=0.2905
# value=-8.025 target=-8.214
# entropy=5.5434 | logit_gap=0.0794 | max_prob=0.2578
# value=-8.230 target=-8.200
# entropy=5.5447 | logit_gap=0.0430 | max_prob=0.2556
# value=-8.481 target=-8.147
# entropy=5.5444 | logit_gap=0.0543 | max_prob=0.2555
# value=-7.891 target=-8.128
# entropy=5.5429 | logit_gap=0.0705 | max_prob=0.2588
# value=-7.802 target=-8.117
# entropy=5.5310 | logit_gap=0.2066 | max_prob=0.2839
# value=-8.009 target=-8.081
# entropy=5.5422 | logit_gap=0.0943 | max_prob=0.2632
# value=-8.533 target=-8.016
# entropy=5.5434 | logit_gap=0.0832 | max_prob=0.2593
# value=-8.026 target=-8.013
# entropy=5.5438 | logit_gap=0.0735 | max_prob=0.2580
# value=-8.008 target=-8.011
# entropy=5.5398 | logit_gap=0.1384 | max_prob=0.2695
# value=-8.025 target=-7.989
# entropy=5.5448 | logit_gap=0.0350 | max_prob=0.2553
# value=-7.910 target=-8.006
# entropy=5.5372 | logit_gap=0.1531 | max_prob=0.2759
# value=-7.970 target=-8.011
# entropy=5.5437 | logit_gap=0.0666 | max_prob=0.2597
# value=-8.388 target=-7.980
# entropy=5.5392 | logit_gap=0.1455 | max_prob=0.2697
# value=-7.873 target=-7.975
# entropy=5.5385 | logit_gap=0.1441 | max_prob=0.2723
# value=-7.543 target=-8.024
# entropy=5.5438 | logit_gap=0.0704 | max_prob=0.2597
# value=-7.765 target=-8.057
# entropy=5.5442 | logit_gap=0.0631 | max_prob=0.2577
# value=-7.889 target=-8.077
# entropy=5.5449 | logit_gap=0.0330 | max_prob=0.2543
# value=-8.227 target=-8.072
# entropy=5.5450 | logit_gap=0.0270 | max_prob=0.2540
# value=-7.628 target=-8.086
# entropy=5.5450 | logit_gap=0.0223 | max_prob=0.2529
# value=-7.739 target=-8.076
# entropy=5.5391 | logit_gap=0.1367 | max_prob=0.2705
# value=-8.039 target=-8.081
# entropy=5.5402 | logit_gap=0.1233 | max_prob=0.2634
# value=-7.813 target=-8.094
# entropy=5.5411 | logit_gap=0.1160 | max_prob=0.2606
# value=-7.881 target=-8.106
# entropy=5.5415 | logit_gap=0.1079 | max_prob=0.2646
# value=-8.600 target=-8.060
# entropy=5.5439 | logit_gap=0.0678 | max_prob=0.2569
# value=-7.839 target=-8.077
# entropy=5.5447 | logit_gap=0.0393 | max_prob=0.2556
# value=-8.225 target=-8.057
# entropy=5.5364 | logit_gap=0.1614 | max_prob=0.2771
# value=-8.135 target=-8.030
# entropy=5.5360 | logit_gap=0.1769 | max_prob=0.2737
# value=-7.998 target=-8.018
# entropy=5.5341 | logit_gap=0.1729 | max_prob=0.2748
# value=-7.715 target=-8.037
# entropy=5.5418 | logit_gap=0.0888 | max_prob=0.2612
# value=-7.877 target=-8.057
# entropy=5.5444 | logit_gap=0.0527 | max_prob=0.2578
# value=-8.094 target=-8.045
# entropy=5.5448 | logit_gap=0.0347 | max_prob=0.2555
# value=-8.254 target=-8.005
# entropy=5.5411 | logit_gap=0.1125 | max_prob=0.2647
# value=-8.022 target=-8.020
# entropy=5.5413 | logit_gap=0.1097 | max_prob=0.2650
# value=-8.248 target=-8.024
# entropy=5.5436 | logit_gap=0.0747 | max_prob=0.2579
# value=-7.771 target=-8.070
# entropy=5.5353 | logit_gap=0.1825 | max_prob=0.2777
# value=-7.583 target=-8.115
# entropy=5.5267 | logit_gap=0.2395 | max_prob=0.2856
# value=-8.050 target=-8.119
# entropy=5.5420 | logit_gap=0.0850 | max_prob=0.2608
# value=-8.042 target=-8.125
# entropy=5.5442 | logit_gap=0.0573 | max_prob=0.2547
# value=-7.568 target=-8.179
# entropy=5.5446 | logit_gap=0.0439 | max_prob=0.2551
# value=-7.913 target=-8.211
# entropy=5.5450 | logit_gap=0.0227 | max_prob=0.2530
# value=-7.480 target=-8.252
# entropy=5.5436 | logit_gap=0.0733 | max_prob=0.2590
# value=-7.941 target=-8.265
# entropy=5.5442 | logit_gap=0.0516 | max_prob=0.2566
# value=-7.660 target=-8.292
# entropy=5.5426 | logit_gap=0.0836 | max_prob=0.2623
# value=-7.986 target=-8.317
# entropy=5.5432 | logit_gap=0.0769 | max_prob=0.2578
# value=-7.869 target=-8.346
# entropy=5.5419 | logit_gap=0.0967 | max_prob=0.2668
# value=-8.080 target=-8.343
# entropy=5.5373 | logit_gap=0.1714 | max_prob=0.2726
# value=-7.753 target=-8.356
# entropy=5.5422 | logit_gap=0.0976 | max_prob=0.2642
# value=-7.859 target=-8.381
# entropy=5.5450 | logit_gap=0.0267 | max_prob=0.2531
# value=-8.242 target=-8.363
# entropy=5.5451 | logit_gap=0.0128 | max_prob=0.2516
# value=-7.725 target=-8.360
# entropy=5.5408 | logit_gap=0.1220 | max_prob=0.2666
# value=-8.022 target=-8.353
# entropy=5.5382 | logit_gap=0.1550 | max_prob=0.2654
# value=-7.961 target=-8.345
# entropy=5.5440 | logit_gap=0.0564 | max_prob=0.2569
# value=-8.185 target=-8.302
# entropy=5.5423 | logit_gap=0.1032 | max_prob=0.2644
# value=-8.274 target=-8.261
# entropy=5.5430 | logit_gap=0.0834 | max_prob=0.2606
# value=-8.001 target=-8.230
# entropy=5.5438 | logit_gap=0.0663 | max_prob=0.2593
# value=-8.483 target=-8.150
# entropy=5.5393 | logit_gap=0.1496 | max_prob=0.2685
# value=-8.033 target=-8.088
# entropy=5.5339 | logit_gap=0.1852 | max_prob=0.2795
# value=-8.064 target=-8.024
# entropy=5.5414 | logit_gap=0.0974 | max_prob=0.2633
# value=-8.656 target=-7.922
# entropy=5.5426 | logit_gap=0.0934 | max_prob=0.2636
# value=-8.266 target=-7.850
# entropy=5.5449 | logit_gap=0.0294 | max_prob=0.2527
# value=-8.479 target=-7.762
# entropy=5.5447 | logit_gap=0.0355 | max_prob=0.2545
# value=-7.903 target=-7.723
# entropy=5.5294 | logit_gap=0.2323 | max_prob=0.2841
# value=-7.902 target=-7.665
# entropy=5.5432 | logit_gap=0.0855 | max_prob=0.2605
# value=-8.503 target=-7.556
# entropy=5.5436 | logit_gap=0.0713 | max_prob=0.2590
# value=-7.446 target=-7.541
# entropy=5.5446 | logit_gap=0.0418 | max_prob=0.2534
# value=-7.841 target=-7.534
# entropy=5.5408 | logit_gap=0.1169 | max_prob=0.2632
# value=-7.923 target=-7.519
# entropy=5.5405 | logit_gap=0.1255 | max_prob=0.2666
# value=-7.692 target=-7.502
# entropy=5.5424 | logit_gap=0.0954 | max_prob=0.2628
# value=-8.448 target=-7.455
# entropy=5.5441 | logit_gap=0.0623 | max_prob=0.2571
# value=-7.235 target=-7.482
# entropy=5.5359 | logit_gap=0.1720 | max_prob=0.2774
# value=-7.723 target=-7.472
# entropy=5.5340 | logit_gap=0.1748 | max_prob=0.2752
# value=-7.826 target=-7.437
# entropy=5.5415 | logit_gap=0.0909 | max_prob=0.2610
# value=-8.189 target=-7.352
# entropy=5.5441 | logit_gap=0.0565 | max_prob=0.2575
# value=-8.639 target=-7.221
# entropy=5.5445 | logit_gap=0.0442 | max_prob=0.2550
# value=-8.232 target=-7.120
# entropy=5.5449 | logit_gap=0.0293 | max_prob=0.2549
# value=-7.964 target=-7.034
# entropy=5.5436 | logit_gap=0.0774 | max_prob=0.2602
# value=-8.031 target=-6.934
# entropy=5.5449 | logit_gap=0.0267 | max_prob=0.2530
# value=-8.434 target=-6.796
# entropy=5.5397 | logit_gap=0.1361 | max_prob=0.2710
# value=-7.993 target=-6.702
# entropy=5.5358 | logit_gap=0.1808 | max_prob=0.2754
# value=-7.899 target=-6.614
# entropy=5.5431 | logit_gap=0.0832 | max_prob=0.2572
# value=-7.888 target=-6.538
# entropy=5.5433 | logit_gap=0.0816 | max_prob=0.2602
# value=-8.519 target=-6.413
# entropy=5.5398 | logit_gap=0.1265 | max_prob=0.2663
# value=-8.090 target=-6.308
# entropy=5.5428 | logit_gap=0.0802 | max_prob=0.2604
# value=-8.107 target=-6.190
# entropy=5.5431 | logit_gap=0.0802 | max_prob=0.2587
# value=-7.920 target=-6.074
# entropy=5.5445 | logit_gap=0.0468 | max_prob=0.2561
# value=-8.258 target=-5.936
# entropy=5.5442 | logit_gap=0.0549 | max_prob=0.2553
# value=-7.910 target=-5.805
# entropy=5.5345 | logit_gap=0.1960 | max_prob=0.2763
# value=-7.716 target=-5.686
# entropy=5.5260 | logit_gap=0.2446 | max_prob=0.2874
# value=-7.843 target=-5.577
# entropy=5.5439 | logit_gap=0.0606 | max_prob=0.2587
# value=-7.701 target=-5.469
# entropy=5.5437 | logit_gap=0.0686 | max_prob=0.2561
# value=-7.876 target=-5.342
# entropy=5.5430 | logit_gap=0.0822 | max_prob=0.2610
# value=-8.043 target=-5.196
# entropy=5.5376 | logit_gap=0.1512 | max_prob=0.2744
# value=-7.529 target=-5.080
# entropy=5.5391 | logit_gap=0.1367 | max_prob=0.2713
# value=-7.497 target=-4.962
# entropy=5.5431 | logit_gap=0.0907 | max_prob=0.2615
# value=-7.283 target=-4.850
# entropy=5.5356 | logit_gap=0.1822 | max_prob=0.2739
# value=-7.662 target=-4.703
# entropy=5.5440 | logit_gap=0.0607 | max_prob=0.2565
# value=-7.481 target=-4.572
# entropy=5.5442 | logit_gap=0.0574 | max_prob=0.2556
# value=-7.353 target=-4.440
# entropy=5.5437 | logit_gap=0.0706 | max_prob=0.2595
# value=-7.357 target=-4.317
# entropy=5.5444 | logit_gap=0.0539 | max_prob=0.2556
# value=-7.426 target=-4.176
# entropy=5.5442 | logit_gap=0.0592 | max_prob=0.2562
# value=-7.523 target=-4.012
# entropy=5.5435 | logit_gap=0.0734 | max_prob=0.2581
# value=-7.341 target=-3.848
# entropy=5.5438 | logit_gap=0.0673 | max_prob=0.2571
# value=-6.720 target=-3.729
# entropy=5.5445 | logit_gap=0.0476 | max_prob=0.2546
# value=-7.013 target=-3.588
# entropy=5.5391 | logit_gap=0.1370 | max_prob=0.2730
# value=-7.102 target=-3.434
# entropy=5.5447 | logit_gap=0.0347 | max_prob=0.2540
# value=-7.217 target=-3.260
# entropy=5.5437 | logit_gap=0.0715 | max_prob=0.2565
# value=-7.388 target=-3.067
# entropy=5.5350 | logit_gap=0.1867 | max_prob=0.2782
# value=-7.193 target=-2.875
# entropy=5.5405 | logit_gap=0.1290 | max_prob=0.2670
# value=-7.397 target=-2.659
# entropy=5.5358 | logit_gap=0.1787 | max_prob=0.2711
# value=-7.449 target=-2.427
# entropy=5.5439 | logit_gap=0.0644 | max_prob=0.2570
# value=-7.426 target=-2.174
# entropy=5.5445 | logit_gap=0.0508 | max_prob=0.2566
# value=-7.141 target=-1.920
# entropy=5.5447 | logit_gap=0.0413 | max_prob=0.2545
# value=-7.208 target=-1.646
# entropy=5.5347 | logit_gap=0.1831 | max_prob=0.2800
# value=-7.638 target=-1.332
# entropy=5.5435 | logit_gap=0.0691 | max_prob=0.2571
# value=-7.287 target=-1.017
# entropy=5.5433 | logit_gap=0.0802 | max_prob=0.2590
# value=-7.364 target=-0.694
# entropy=5.5445 | logit_gap=0.0501 | max_prob=0.2550
# value=-7.241 target=-0.357
# entropy=5.5064 | logit_gap=0.3461 | max_prob=0.3065
# value=-7.204 target=0.000
# critic_epoch=5 loss=2.7810 grad=5.7232
#
# encoder_grad : 1.1636
# actor_grad   : 1.9358
# critic_grad  : 5.7232
# ExplainedVar : -100.313
# Value mean   : -7.962
# Value std    : 0.099
# Return mean  : -7.554
# Return std   : 0.532
# TD mean      : 1.057
# TD max       : 7.204
#
#
# ======================================================================
# Reward      : -0.0883
# Actor Loss  : -0.1528
# Critic Loss : 2.7810
# Entropy     : 5.5413
# ExplainedVar: -100.313
# TD mean/max : 1.057 / 7.204
# ======================================================================
#
# ValueNorm mean=-7.550 std=1.369
# ADV: mean=0.0000 std=1.0000 min=-3.5664 max=2.3970
# emb_mean=0.0575 emb_std=0.0751
# first_node_emb: [0.06245718 0.06043495 0.17273122 0.2552097  0.        ]
# entropy=5.5437 | logit_gap=0.0755 | max_prob=0.2587
# Counter({1: 293, 3: 261, 0: 246, 2: 224})
# value=-6.142 target=-6.545
# entropy=5.5436 | logit_gap=0.0758 | max_prob=0.2586
# value=-6.037 target=-6.641
# entropy=5.5447 | logit_gap=0.0327 | max_prob=0.2541
# value=-6.473 target=-6.721
# entropy=5.5432 | logit_gap=0.0756 | max_prob=0.2611
# value=-7.378 target=-6.758
# entropy=5.5421 | logit_gap=0.1017 | max_prob=0.2639
# value=-7.280 target=-6.786
# entropy=5.5437 | logit_gap=0.0723 | max_prob=0.2572
# value=-7.170 target=-6.811
# entropy=5.5445 | logit_gap=0.0514 | max_prob=0.2551
# value=-7.061 target=-6.844
# entropy=5.5447 | logit_gap=0.0394 | max_prob=0.2539
# value=-6.700 target=-6.898
# entropy=5.5446 | logit_gap=0.0412 | max_prob=0.2549
# value=-6.790 target=-6.950
# entropy=5.5442 | logit_gap=0.0593 | max_prob=0.2563
# value=-6.565 target=-7.007
# entropy=5.5446 | logit_gap=0.0471 | max_prob=0.2553
# value=-7.122 target=-7.036
# entropy=5.5450 | logit_gap=0.0215 | max_prob=0.2531
# value=-7.118 target=-7.051
# entropy=5.5235 | logit_gap=0.2552 | max_prob=0.2915
# value=-7.659 target=-7.035
# entropy=5.5267 | logit_gap=0.2400 | max_prob=0.2838
# value=-7.519 target=-7.039
# entropy=5.5412 | logit_gap=0.0977 | max_prob=0.2624
# value=-7.451 target=-7.034
# entropy=5.5443 | logit_gap=0.0537 | max_prob=0.2579
# value=-7.449 target=-7.036
# entropy=5.5441 | logit_gap=0.0560 | max_prob=0.2554
# value=-6.987 target=-7.066
# entropy=5.5452 | logit_gap=0.0089 | max_prob=0.2510
# value=-7.162 target=-7.080
# entropy=5.5429 | logit_gap=0.0750 | max_prob=0.2591
# value=-7.301 target=-7.093
# entropy=5.5353 | logit_gap=0.1864 | max_prob=0.2714
# value=-7.300 target=-7.105
# entropy=5.5353 | logit_gap=0.1827 | max_prob=0.2698
# value=-7.343 target=-7.117
# entropy=5.5440 | logit_gap=0.0625 | max_prob=0.2552
# value=-7.677 target=-7.105
# entropy=5.5435 | logit_gap=0.0757 | max_prob=0.2612
# value=-7.163 target=-7.127
# entropy=5.5315 | logit_gap=0.2054 | max_prob=0.2834
# value=-7.408 target=-7.153
# entropy=5.5439 | logit_gap=0.0582 | max_prob=0.2580
# value=-7.223 target=-7.188
# entropy=5.5443 | logit_gap=0.0538 | max_prob=0.2550
# value=-7.494 target=-7.193
# entropy=5.5429 | logit_gap=0.0738 | max_prob=0.2593
# value=-7.534 target=-7.188
# entropy=5.5419 | logit_gap=0.1016 | max_prob=0.2641
# value=-7.713 target=-7.181
# entropy=5.5431 | logit_gap=0.0909 | max_prob=0.2618
# value=-7.281 target=-7.204
# entropy=5.5448 | logit_gap=0.0324 | max_prob=0.2538
# value=-7.023 target=-7.229
# entropy=5.5419 | logit_gap=0.0972 | max_prob=0.2640
# value=-7.589 target=-7.228
# entropy=5.5432 | logit_gap=0.0767 | max_prob=0.2610
# value=-7.563 target=-7.226
# entropy=5.5439 | logit_gap=0.0672 | max_prob=0.2584
# value=-6.999 target=-7.249
# entropy=5.5439 | logit_gap=0.0656 | max_prob=0.2568
# value=-7.879 target=-7.208
# entropy=5.5433 | logit_gap=0.0790 | max_prob=0.2588
# value=-7.475 target=-7.204
# entropy=5.5428 | logit_gap=0.0927 | max_prob=0.2590
# value=-7.583 target=-7.183
# entropy=5.5400 | logit_gap=0.1328 | max_prob=0.2700
# value=-7.623 target=-7.178
# entropy=5.5336 | logit_gap=0.2028 | max_prob=0.2774
# value=-7.276 target=-7.183
# entropy=5.5434 | logit_gap=0.0837 | max_prob=0.2610
# value=-7.375 target=-7.175
# entropy=5.5445 | logit_gap=0.0459 | max_prob=0.2559
# value=-7.519 target=-7.161
# entropy=5.5361 | logit_gap=0.1642 | max_prob=0.2773
# value=-7.453 target=-7.161
# entropy=5.5390 | logit_gap=0.1366 | max_prob=0.2682
# value=-7.576 target=-7.154
# entropy=5.5400 | logit_gap=0.1268 | max_prob=0.2644
# value=-7.484 target=-7.170
# entropy=5.5444 | logit_gap=0.0515 | max_prob=0.2578
# value=-7.407 target=-7.183
# entropy=5.5447 | logit_gap=0.0407 | max_prob=0.2559
# value=-7.211 target=-7.192
# entropy=5.5434 | logit_gap=0.0754 | max_prob=0.2589
# value=-7.593 target=-7.181
# entropy=5.5357 | logit_gap=0.1833 | max_prob=0.2719
# value=-7.413 target=-7.173
# entropy=5.5394 | logit_gap=0.1344 | max_prob=0.2673
# value=-7.267 target=-7.178
# entropy=5.5445 | logit_gap=0.0441 | max_prob=0.2535
# value=-7.277 target=-7.172
# entropy=5.5435 | logit_gap=0.0807 | max_prob=0.2609
# value=-6.776 target=-7.213
# entropy=5.5447 | logit_gap=0.0396 | max_prob=0.2533
# value=-7.002 target=-7.264
# entropy=5.5370 | logit_gap=0.1561 | max_prob=0.2767
# value=-7.401 target=-7.291
# entropy=5.5440 | logit_gap=0.0627 | max_prob=0.2592
# value=-7.189 target=-7.334
# entropy=5.5420 | logit_gap=0.0958 | max_prob=0.2661
# value=-7.312 target=-7.379
# entropy=5.5448 | logit_gap=0.0354 | max_prob=0.2556
# value=-7.487 target=-7.401
# entropy=5.5450 | logit_gap=0.0230 | max_prob=0.2533
# value=-6.966 target=-7.450
# entropy=5.5417 | logit_gap=0.1009 | max_prob=0.2671
# value=-7.496 target=-7.479
# entropy=5.5446 | logit_gap=0.0373 | max_prob=0.2542
# value=-7.189 target=-7.510
# entropy=5.5430 | logit_gap=0.0702 | max_prob=0.2592
# value=-7.308 target=-7.547
# entropy=5.5423 | logit_gap=0.0896 | max_prob=0.2626
# value=-8.126 target=-7.520
# entropy=5.5437 | logit_gap=0.0766 | max_prob=0.2596
# value=-7.521 target=-7.512
# entropy=5.5448 | logit_gap=0.0370 | max_prob=0.2554
# value=-7.801 target=-7.486
# entropy=5.5448 | logit_gap=0.0314 | max_prob=0.2541
# value=-7.924 target=-7.441
# entropy=5.5449 | logit_gap=0.0277 | max_prob=0.2536
# value=-8.090 target=-7.375
# entropy=5.5444 | logit_gap=0.0537 | max_prob=0.2572
# value=-7.705 target=-7.345
# entropy=5.5243 | logit_gap=0.2535 | max_prob=0.2907
# value=-7.573 target=-7.345
# entropy=5.5404 | logit_gap=0.1273 | max_prob=0.2625
# value=-7.511 target=-7.353
# entropy=5.5426 | logit_gap=0.0972 | max_prob=0.2611
# value=-7.422 target=-7.383
# entropy=5.5359 | logit_gap=0.1741 | max_prob=0.2700
# value=-7.523 target=-7.401
# entropy=5.5308 | logit_gap=0.2093 | max_prob=0.2826
# value=-7.679 target=-7.398
# entropy=5.5415 | logit_gap=0.1049 | max_prob=0.2625
# value=-7.615 target=-7.399
# entropy=5.5414 | logit_gap=0.1116 | max_prob=0.2654
# value=-7.303 target=-7.427
# entropy=5.5449 | logit_gap=0.0311 | max_prob=0.2550
# value=-7.600 target=-7.438
# entropy=5.5356 | logit_gap=0.1795 | max_prob=0.2771
# value=-7.270 target=-7.465
# entropy=5.5435 | logit_gap=0.0720 | max_prob=0.2564
# value=-7.572 target=-7.473
# entropy=5.5427 | logit_gap=0.0790 | max_prob=0.2592
# value=-7.635 target=-7.474
# entropy=5.5446 | logit_gap=0.0411 | max_prob=0.2528
# value=-7.570 target=-7.464
# entropy=5.5442 | logit_gap=0.0549 | max_prob=0.2546
# value=-7.358 target=-7.477
# entropy=5.5448 | logit_gap=0.0374 | max_prob=0.2557
# value=-7.779 target=-7.447
# entropy=5.5443 | logit_gap=0.0543 | max_prob=0.2548
# value=-7.251 target=-7.452
# entropy=5.5442 | logit_gap=0.0574 | max_prob=0.2574
# value=-7.425 target=-7.448
# entropy=5.5264 | logit_gap=0.2451 | max_prob=0.2889
# value=-7.452 target=-7.455
# entropy=5.5408 | logit_gap=0.1208 | max_prob=0.2610
# value=-7.440 target=-7.468
# entropy=5.5441 | logit_gap=0.0596 | max_prob=0.2555
# value=-7.149 target=-7.522
# entropy=5.5359 | logit_gap=0.1800 | max_prob=0.2755
# value=-7.355 target=-7.558
# entropy=5.5440 | logit_gap=0.0589 | max_prob=0.2555
# value=-7.585 target=-7.578
# entropy=5.5409 | logit_gap=0.1116 | max_prob=0.2623
# value=-7.694 target=-7.591
# entropy=5.5443 | logit_gap=0.0554 | max_prob=0.2580
# value=-7.455 target=-7.621
# entropy=5.5360 | logit_gap=0.1781 | max_prob=0.2756
# value=-7.293 target=-7.650
# entropy=5.5430 | logit_gap=0.0926 | max_prob=0.2607
# value=-7.566 target=-7.653
# entropy=5.5443 | logit_gap=0.0533 | max_prob=0.2545
# value=-7.262 target=-7.694
# entropy=5.5445 | logit_gap=0.0508 | max_prob=0.2553
# value=-7.459 target=-7.727
# entropy=5.5417 | logit_gap=0.1069 | max_prob=0.2652
# value=-7.767 target=-7.735
# entropy=5.5365 | logit_gap=0.1752 | max_prob=0.2717
# value=-7.593 target=-7.743
# entropy=5.5404 | logit_gap=0.1289 | max_prob=0.2630
# value=-7.762 target=-7.728
# entropy=5.5422 | logit_gap=0.0858 | max_prob=0.2611
# value=-7.546 target=-7.727
# entropy=5.5392 | logit_gap=0.1337 | max_prob=0.2677
# value=-7.384 target=-7.742
# entropy=5.5432 | logit_gap=0.0881 | max_prob=0.2605
# value=-7.177 target=-7.785
# entropy=5.5445 | logit_gap=0.0466 | max_prob=0.2544
# value=-7.559 target=-7.768
# entropy=5.5444 | logit_gap=0.0492 | max_prob=0.2566
# value=-7.969 target=-7.721
# entropy=5.5445 | logit_gap=0.0496 | max_prob=0.2546
# value=-7.517 target=-7.715
# entropy=5.5359 | logit_gap=0.1771 | max_prob=0.2698
# value=-7.682 target=-7.701
# entropy=5.5272 | logit_gap=0.2385 | max_prob=0.2836
# value=-7.804 target=-7.684
# entropy=5.5407 | logit_gap=0.1149 | max_prob=0.2627
# value=-7.692 target=-7.670
# entropy=5.5446 | logit_gap=0.0445 | max_prob=0.2543
# value=-7.669 target=-7.629
# entropy=5.5437 | logit_gap=0.0755 | max_prob=0.2592
# value=-7.253 target=-7.624
# entropy=5.5438 | logit_gap=0.0720 | max_prob=0.2579
# value=-7.430 target=-7.611
# entropy=5.5401 | logit_gap=0.1196 | max_prob=0.2656
# value=-7.950 target=-7.581
# entropy=5.5435 | logit_gap=0.0785 | max_prob=0.2586
# value=-7.693 target=-7.542
# entropy=5.5446 | logit_gap=0.0415 | max_prob=0.2535
# value=-7.405 target=-7.533
# entropy=5.5445 | logit_gap=0.0454 | max_prob=0.2540
# value=-7.743 target=-7.488
# entropy=5.5338 | logit_gap=0.1920 | max_prob=0.2806
# value=-7.532 target=-7.451
# entropy=5.5448 | logit_gap=0.0345 | max_prob=0.2531
# value=-7.625 target=-7.410
# entropy=5.5449 | logit_gap=0.0310 | max_prob=0.2529
# value=-7.411 target=-7.409
# entropy=5.5443 | logit_gap=0.0528 | max_prob=0.2571
# value=-7.022 target=-7.436
# entropy=5.5440 | logit_gap=0.0638 | max_prob=0.2578
# value=-7.666 target=-7.418
# entropy=5.5448 | logit_gap=0.0343 | max_prob=0.2535
# value=-7.887 target=-7.368
# entropy=5.5450 | logit_gap=0.0203 | max_prob=0.2524
# value=-7.935 target=-7.302
# entropy=5.5451 | logit_gap=0.0158 | max_prob=0.2523
# value=-7.826 target=-7.238
# entropy=5.5451 | logit_gap=0.0143 | max_prob=0.2518
# value=-7.554 target=-7.203
# entropy=5.5246 | logit_gap=0.2532 | max_prob=0.2894
# value=-7.524 target=-7.209
# entropy=5.5437 | logit_gap=0.0660 | max_prob=0.2593
# value=-7.479 target=-7.219
# entropy=5.5443 | logit_gap=0.0558 | max_prob=0.2564
# value=-7.325 target=-7.234
# entropy=5.5238 | logit_gap=0.2475 | max_prob=0.2938
# value=-7.292 target=-7.257
# entropy=5.5406 | logit_gap=0.1245 | max_prob=0.2638
# value=-7.366 target=-7.278
# entropy=5.5409 | logit_gap=0.1136 | max_prob=0.2651
# value=-7.761 target=-7.285
# entropy=5.5440 | logit_gap=0.0642 | max_prob=0.2568
# value=-6.579 target=-7.357
# entropy=5.5447 | logit_gap=0.0414 | max_prob=0.2543
# value=-7.271 target=-7.395
# entropy=5.5369 | logit_gap=0.1557 | max_prob=0.2724
# value=-6.864 target=-7.448
# entropy=5.5408 | logit_gap=0.1091 | max_prob=0.2621
# value=-7.779 target=-7.444
# entropy=5.5445 | logit_gap=0.0405 | max_prob=0.2550
# value=-7.537 target=-7.459
# entropy=5.5435 | logit_gap=0.0727 | max_prob=0.2577
# value=-7.458 target=-7.467
# entropy=5.5443 | logit_gap=0.0501 | max_prob=0.2556
# value=-7.111 target=-7.483
# entropy=5.5451 | logit_gap=0.0193 | max_prob=0.2526
# value=-7.324 target=-7.475
# entropy=5.5448 | logit_gap=0.0335 | max_prob=0.2531
# value=-7.550 target=-7.449
# entropy=5.5405 | logit_gap=0.1252 | max_prob=0.2689
# value=-7.684 target=-7.407
# entropy=5.5440 | logit_gap=0.0592 | max_prob=0.2569
# value=-7.580 target=-7.381
# entropy=5.5401 | logit_gap=0.1293 | max_prob=0.2636
# value=-7.660 target=-7.355
# entropy=5.5405 | logit_gap=0.1227 | max_prob=0.2629
# value=-7.521 target=-7.358
# entropy=5.5436 | logit_gap=0.0655 | max_prob=0.2593
# value=-7.389 target=-7.339
# entropy=5.5443 | logit_gap=0.0491 | max_prob=0.2587
# value=-7.627 target=-7.316
# entropy=5.5442 | logit_gap=0.0546 | max_prob=0.2575
# value=-7.134 target=-7.375
# entropy=5.5446 | logit_gap=0.0429 | max_prob=0.2560
# value=-6.971 target=-7.440
# entropy=5.5320 | logit_gap=0.2002 | max_prob=0.2820
# value=-7.624 target=-7.451
# entropy=5.5438 | logit_gap=0.0623 | max_prob=0.2589
# value=-7.448 target=-7.477
# entropy=5.5439 | logit_gap=0.0696 | max_prob=0.2577
# value=-6.952 target=-7.528
# entropy=5.5260 | logit_gap=0.2430 | max_prob=0.2879
# value=-7.595 target=-7.538
# entropy=5.5441 | logit_gap=0.0638 | max_prob=0.2590
# value=-7.422 target=-7.561
# entropy=5.5441 | logit_gap=0.0606 | max_prob=0.2563
# value=-7.111 target=-7.595
# entropy=5.5408 | logit_gap=0.1125 | max_prob=0.2632
# value=-7.677 target=-7.592
# entropy=5.5436 | logit_gap=0.0684 | max_prob=0.2595
# value=-7.297 target=-7.619
# entropy=5.5436 | logit_gap=0.0766 | max_prob=0.2580
# value=-7.149 target=-7.661
# entropy=5.5444 | logit_gap=0.0491 | max_prob=0.2543
# value=-7.051 target=-7.759
# entropy=5.5435 | logit_gap=0.0821 | max_prob=0.2594
# value=-7.020 target=-7.856
# entropy=5.5429 | logit_gap=0.0892 | max_prob=0.2614
# value=-7.584 target=-7.898
# entropy=5.5408 | logit_gap=0.1232 | max_prob=0.2667
# value=-7.619 target=-7.928
# entropy=5.5403 | logit_gap=0.1179 | max_prob=0.2638
# value=-7.672 target=-7.959
# entropy=5.5417 | logit_gap=0.0933 | max_prob=0.2627
# value=-7.532 target=-8.000
# entropy=5.5431 | logit_gap=0.0902 | max_prob=0.2602
# value=-7.819 target=-8.020
# entropy=5.5436 | logit_gap=0.0767 | max_prob=0.2583
# value=-7.747 target=-8.040
# entropy=5.5313 | logit_gap=0.1988 | max_prob=0.2813
# value=-7.724 target=-8.062
# entropy=5.5435 | logit_gap=0.0705 | max_prob=0.2600
# value=-7.684 target=-8.094
# entropy=5.5441 | logit_gap=0.0567 | max_prob=0.2578
# value=-6.991 target=-8.155
# entropy=5.5449 | logit_gap=0.0302 | max_prob=0.2540
# value=-7.248 target=-8.199
# entropy=5.5451 | logit_gap=0.0118 | max_prob=0.2516
# value=-7.406 target=-8.230
# entropy=5.5412 | logit_gap=0.1173 | max_prob=0.2668
# value=-7.644 target=-8.258
# entropy=5.5415 | logit_gap=0.1095 | max_prob=0.2616
# value=-7.765 target=-8.273
# entropy=5.5446 | logit_gap=0.0454 | max_prob=0.2567
# value=-8.161 target=-8.256
# entropy=5.5395 | logit_gap=0.1284 | max_prob=0.2705
# value=-8.014 target=-8.231
# entropy=5.5393 | logit_gap=0.1324 | max_prob=0.2691
# value=-7.663 target=-8.221
# entropy=5.5447 | logit_gap=0.0399 | max_prob=0.2536
# value=-7.784 target=-8.238
# entropy=5.5385 | logit_gap=0.1452 | max_prob=0.2735
# value=-7.812 target=-8.279
# entropy=5.5414 | logit_gap=0.1040 | max_prob=0.2638
# value=-7.766 target=-8.315
# entropy=5.5446 | logit_gap=0.0472 | max_prob=0.2555
# value=-8.089 target=-8.317
# entropy=5.5437 | logit_gap=0.0735 | max_prob=0.2599
# value=-7.087 target=-8.387
# entropy=5.5442 | logit_gap=0.0556 | max_prob=0.2556
# value=-7.839 target=-8.412
# entropy=5.5435 | logit_gap=0.0717 | max_prob=0.2606
# value=-7.430 target=-8.466
# entropy=5.5444 | logit_gap=0.0477 | max_prob=0.2550
# value=-7.945 target=-8.490
# entropy=5.5417 | logit_gap=0.1015 | max_prob=0.2667
# value=-7.656 target=-8.534
# entropy=5.5425 | logit_gap=0.0932 | max_prob=0.2604
# value=-7.878 target=-8.566
# entropy=5.5428 | logit_gap=0.0863 | max_prob=0.2593
# value=-7.984 target=-8.600
# entropy=5.5418 | logit_gap=0.0966 | max_prob=0.2621
# value=-8.010 target=-8.616
# entropy=5.5437 | logit_gap=0.0731 | max_prob=0.2586
# value=-8.289 target=-8.606
# entropy=5.5432 | logit_gap=0.0840 | max_prob=0.2587
# value=-7.998 target=-8.599
# entropy=5.5445 | logit_gap=0.0448 | max_prob=0.2538
# value=-8.418 target=-8.559
# entropy=5.5435 | logit_gap=0.0729 | max_prob=0.2560
# value=-7.777 target=-8.603
# entropy=5.5363 | logit_gap=0.1741 | max_prob=0.2725
# value=-7.723 target=-8.653
# entropy=5.5428 | logit_gap=0.0796 | max_prob=0.2600
# value=-7.790 target=-8.701
# entropy=5.5432 | logit_gap=0.0711 | max_prob=0.2587
# value=-8.316 target=-8.702
# entropy=5.5438 | logit_gap=0.0649 | max_prob=0.2579
# value=-7.812 target=-8.737
# entropy=5.5441 | logit_gap=0.0622 | max_prob=0.2581
# value=-8.173 target=-8.740
# entropy=5.5445 | logit_gap=0.0495 | max_prob=0.2576
# value=-8.286 target=-8.740
# entropy=5.5440 | logit_gap=0.0680 | max_prob=0.2593
# value=-7.364 target=-8.783
# entropy=5.5448 | logit_gap=0.0322 | max_prob=0.2532
# value=-8.238 target=-8.772
# entropy=5.5449 | logit_gap=0.0316 | max_prob=0.2534
# value=-7.648 target=-8.821
# entropy=5.5446 | logit_gap=0.0478 | max_prob=0.2564
# value=-8.006 target=-8.860
# entropy=5.5358 | logit_gap=0.1731 | max_prob=0.2786
# value=-8.116 target=-8.892
# entropy=5.5437 | logit_gap=0.0748 | max_prob=0.2597
# value=-8.054 target=-8.879
# entropy=5.5442 | logit_gap=0.0561 | max_prob=0.2550
# value=-8.769 target=-8.801
# entropy=5.5435 | logit_gap=0.0740 | max_prob=0.2616
# value=-7.903 target=-8.791
# entropy=5.5445 | logit_gap=0.0440 | max_prob=0.2553
# value=-8.758 target=-8.724
# entropy=5.5417 | logit_gap=0.1038 | max_prob=0.2650
# value=-8.266 target=-8.713
# entropy=5.5416 | logit_gap=0.0999 | max_prob=0.2623
# value=-8.321 target=-8.691
# entropy=5.5424 | logit_gap=0.0935 | max_prob=0.2603
# value=-8.027 target=-8.714
# entropy=5.5435 | logit_gap=0.0748 | max_prob=0.2601
# value=-7.611 target=-8.737
# entropy=5.5432 | logit_gap=0.0750 | max_prob=0.2584
# value=-8.193 target=-8.718
# entropy=5.5260 | logit_gap=0.2404 | max_prob=0.2866
# value=-8.219 target=-8.680
# entropy=5.5403 | logit_gap=0.1308 | max_prob=0.2644
# value=-8.297 target=-8.638
# entropy=5.5439 | logit_gap=0.0695 | max_prob=0.2583
# value=-8.240 target=-8.576
# entropy=5.5446 | logit_gap=0.0446 | max_prob=0.2568
# value=-8.497 target=-8.501
# entropy=5.5255 | logit_gap=0.2390 | max_prob=0.2898
# value=-8.435 target=-8.401
# entropy=5.5404 | logit_gap=0.1126 | max_prob=0.2642
# value=-8.350 target=-8.301
# entropy=5.5446 | logit_gap=0.0446 | max_prob=0.2541
# value=-8.205 target=-8.246
# entropy=5.5436 | logit_gap=0.0732 | max_prob=0.2592
# value=-7.834 target=-8.204
# entropy=5.5448 | logit_gap=0.0343 | max_prob=0.2542
# value=-8.094 target=-8.174
# entropy=5.5447 | logit_gap=0.0376 | max_prob=0.2549
# value=-8.136 target=-8.144
# entropy=5.5371 | logit_gap=0.1632 | max_prob=0.2749
# value=-7.611 target=-8.163
# entropy=5.5436 | logit_gap=0.0637 | max_prob=0.2569
# value=-7.469 target=-8.209
# entropy=5.5325 | logit_gap=0.1927 | max_prob=0.2794
# value=-7.331 target=-8.300
# entropy=5.5402 | logit_gap=0.1201 | max_prob=0.2627
# value=-7.957 target=-8.313
# entropy=5.5422 | logit_gap=0.0949 | max_prob=0.2641
# value=-7.898 target=-8.314
# entropy=5.5435 | logit_gap=0.0789 | max_prob=0.2591
# value=-7.990 target=-8.290
# entropy=5.5448 | logit_gap=0.0325 | max_prob=0.2538
# value=-7.644 target=-8.300
# entropy=5.5406 | logit_gap=0.1223 | max_prob=0.2662
# value=-7.718 target=-8.331
# entropy=5.5408 | logit_gap=0.1207 | max_prob=0.2609
# value=-7.841 target=-8.331
# entropy=5.5441 | logit_gap=0.0590 | max_prob=0.2552
# value=-7.606 target=-8.349
# entropy=5.5446 | logit_gap=0.0429 | max_prob=0.2557
# value=-7.994 target=-8.340
# entropy=5.5261 | logit_gap=0.2475 | max_prob=0.2887
# value=-7.781 target=-8.335
# entropy=5.5414 | logit_gap=0.1099 | max_prob=0.2643
# value=-8.119 target=-8.303
# entropy=5.5429 | logit_gap=0.0757 | max_prob=0.2595
# value=-7.706 target=-8.281
# entropy=5.5433 | logit_gap=0.0746 | max_prob=0.2605
# value=-8.240 target=-8.236
# entropy=5.5431 | logit_gap=0.0841 | max_prob=0.2597
# value=-7.831 target=-8.244
# entropy=5.5443 | logit_gap=0.0539 | max_prob=0.2584
# value=-7.875 target=-8.253
# entropy=5.5410 | logit_gap=0.1187 | max_prob=0.2672
# value=-8.004 target=-8.236
# entropy=5.5440 | logit_gap=0.0562 | max_prob=0.2571
# value=-7.383 target=-8.255
# entropy=5.5421 | logit_gap=0.0952 | max_prob=0.2645
# value=-7.984 target=-8.250
# entropy=5.5358 | logit_gap=0.1803 | max_prob=0.2750
# value=-7.716 target=-8.257
# entropy=5.5406 | logit_gap=0.1230 | max_prob=0.2639
# value=-7.936 target=-8.248
# entropy=5.5443 | logit_gap=0.0481 | max_prob=0.2564
# value=-7.774 target=-8.238
# entropy=5.5428 | logit_gap=0.0840 | max_prob=0.2624
# value=-8.175 target=-8.217
# entropy=5.5363 | logit_gap=0.1730 | max_prob=0.2737
# value=-7.924 target=-8.195
# entropy=5.5438 | logit_gap=0.0666 | max_prob=0.2552
# value=-7.852 target=-8.199
# entropy=5.5435 | logit_gap=0.0799 | max_prob=0.2590
# value=-8.015 target=-8.177
# entropy=5.5435 | logit_gap=0.0775 | max_prob=0.2585
# value=-8.104 target=-8.156
# entropy=5.5437 | logit_gap=0.0742 | max_prob=0.2580
# value=-8.227 target=-8.119
# entropy=5.5329 | logit_gap=0.2118 | max_prob=0.2817
# value=-7.139 target=-8.196
# entropy=5.5441 | logit_gap=0.0501 | max_prob=0.2559
# value=-7.949 target=-8.211
# entropy=5.5406 | logit_gap=0.1216 | max_prob=0.2641
# value=-7.715 target=-8.237
# entropy=5.5439 | logit_gap=0.0680 | max_prob=0.2567
# value=-7.920 target=-8.226
# entropy=5.5419 | logit_gap=0.1046 | max_prob=0.2660
# value=-7.713 target=-8.243
# entropy=5.5427 | logit_gap=0.0983 | max_prob=0.2607
# value=-7.750 target=-8.287
# entropy=5.5443 | logit_gap=0.0480 | max_prob=0.2563
# value=-7.750 target=-8.326
# entropy=5.5449 | logit_gap=0.0309 | max_prob=0.2537
# value=-7.997 target=-8.337
# entropy=5.5252 | logit_gap=0.2513 | max_prob=0.2881
# value=-7.628 target=-8.362
# entropy=5.5406 | logit_gap=0.1087 | max_prob=0.2634
# value=-8.378 target=-8.338
# entropy=5.5436 | logit_gap=0.0625 | max_prob=0.2581
# value=-8.121 target=-8.326
# critic_epoch=5 loss=0.3743 grad=7.9745
#
# encoder_grad : 2.1353
# actor_grad   : 3.3085
# critic_grad  : 7.9745
# ExplainedVar : -0.076
# Value mean   : -7.601
# Value std    : 0.102
# ...
# value=-7.366 target=-7.189
# entropy=5.5451 | logit_gap=0.0188 | max_prob=0.2526
# value=-7.476 target=-7.160
# entropy=5.5428 | logit_gap=0.0827 | max_prob=0.2605
# value=-7.575 target=-7.113
# entropy=5.5378 | logit_gap=0.1642 | max_prob=0.2707
# value=-7.578 target=-7.064
# entropy=5.5359 | logit_gap=0.1691 | max_prob=0.2754
# value=-7.443 target=-7.026
# entropy=5.5390 | logit_gap=0.1398 | max_prob=0.2666
# value=-7.648 target=-6.988
# entropy=5.5408 | logit_gap=0.1124 | max_prob=0.2637
# value=-7.460 target=-6.950
# entropy=5.5444 | logit_gap=0.0514 | max_prob=0.2547
# value=-7.463 target=-6.941
# entropy=5.5422 | logit_gap=0.1010 | max_prob=0.2588
# value=-6.923 target=-6.949
# entropy=5.5105 | logit_gap=0.3218 | max_prob=0.3033
# value=-7.192 target=-6.954
# entropy=5.5419 | logit_gap=0.1031 | max_prob=0.2626
# value=-7.077 target=-6.968
# entropy=5.5443 | logit_gap=0.0521 | max_prob=0.2546
# value=-7.039 target=-7.002
# entropy=5.5434 | logit_gap=0.0737 | max_prob=0.2566
# value=-6.652 target=-7.052
# entropy=5.5352 | logit_gap=0.1758 | max_prob=0.2767
# value=-6.946 target=-7.093
# entropy=5.5397 | logit_gap=0.1356 | max_prob=0.2635
# value=-7.036 target=-7.118
# entropy=5.5443 | logit_gap=0.0555 | max_prob=0.2567
# value=-7.025 target=-7.153
# entropy=5.5432 | logit_gap=0.0823 | max_prob=0.2572
# value=-6.921 target=-7.180
# entropy=5.5445 | logit_gap=0.0476 | max_prob=0.2541
# value=-7.558 target=-7.173
# entropy=5.5326 | logit_gap=0.2153 | max_prob=0.2791
# value=-7.027 target=-7.191
# entropy=5.5438 | logit_gap=0.0680 | max_prob=0.2562
# value=-7.155 target=-7.213
# entropy=5.5442 | logit_gap=0.0577 | max_prob=0.2555
# value=-6.746 target=-7.240
# entropy=5.5442 | logit_gap=0.0615 | max_prob=0.2577
# value=-7.107 target=-7.244
# entropy=5.5441 | logit_gap=0.0575 | max_prob=0.2559
# value=-6.800 target=-7.270
# entropy=5.5447 | logit_gap=0.0374 | max_prob=0.2560
# value=-7.101 target=-7.287
# entropy=5.5442 | logit_gap=0.0546 | max_prob=0.2542
# value=-6.805 target=-7.313
# entropy=5.5192 | logit_gap=0.2859 | max_prob=0.2968
# value=-7.269 target=-7.329
# entropy=5.5383 | logit_gap=0.1488 | max_prob=0.2634
# value=-7.228 target=-7.349
# entropy=5.5434 | logit_gap=0.0767 | max_prob=0.2605
# value=-7.189 target=-7.353
# entropy=5.5411 | logit_gap=0.1092 | max_prob=0.2688
# value=-7.702 target=-7.312
# entropy=5.5438 | logit_gap=0.0627 | max_prob=0.2565
# value=-6.785 target=-7.335
# entropy=5.5420 | logit_gap=0.0948 | max_prob=0.2631
# value=-7.747 target=-7.298
# entropy=5.5441 | logit_gap=0.0625 | max_prob=0.2577
# value=-7.513 target=-7.263
# entropy=5.5371 | logit_gap=0.1614 | max_prob=0.2752
# value=-7.209 target=-7.261
# entropy=5.5446 | logit_gap=0.0413 | max_prob=0.2543
# value=-7.231 target=-7.255
# entropy=5.5447 | logit_gap=0.0379 | max_prob=0.2551
# value=-7.250 target=-7.234
# entropy=5.5451 | logit_gap=0.0147 | max_prob=0.2517
# value=-7.209 target=-7.203
# entropy=5.5438 | logit_gap=0.0682 | max_prob=0.2574
# value=-6.831 target=-7.198
# entropy=5.5437 | logit_gap=0.0742 | max_prob=0.2576
# value=-7.064 target=-7.231
# entropy=5.5421 | logit_gap=0.1035 | max_prob=0.2590
# value=-6.999 target=-7.264
# entropy=5.5438 | logit_gap=0.0643 | max_prob=0.2586
# value=-7.260 target=-7.273
# entropy=5.5195 | logit_gap=0.2870 | max_prob=0.2953
# value=-7.304 target=-7.271
# entropy=5.5317 | logit_gap=0.2119 | max_prob=0.2719
# value=-7.337 target=-7.255
# entropy=5.5439 | logit_gap=0.0627 | max_prob=0.2608
# value=-7.273 target=-7.238
# entropy=5.5424 | logit_gap=0.0999 | max_prob=0.2591
# value=-7.092 target=-7.227
# entropy=5.5409 | logit_gap=0.1169 | max_prob=0.2671
# value=-7.215 target=-7.251
# entropy=5.5424 | logit_gap=0.0980 | max_prob=0.2586
# value=-6.876 target=-7.289
# entropy=5.5425 | logit_gap=0.1007 | max_prob=0.2627
# value=-7.233 target=-7.298
# entropy=5.5430 | logit_gap=0.0870 | max_prob=0.2578
# value=-7.421 target=-7.276
# entropy=5.5382 | logit_gap=0.1505 | max_prob=0.2683
# value=-7.730 target=-7.242
# entropy=5.5415 | logit_gap=0.0982 | max_prob=0.2629
# value=-7.361 target=-7.238
# entropy=5.5417 | logit_gap=0.0959 | max_prob=0.2620
# value=-7.348 target=-7.235
# entropy=5.5445 | logit_gap=0.0487 | max_prob=0.2566
# value=-6.996 target=-7.250
# entropy=5.5449 | logit_gap=0.0297 | max_prob=0.2540
# value=-7.004 target=-7.268
# entropy=5.5383 | logit_gap=0.1612 | max_prob=0.2715
# value=-7.050 target=-7.291
# entropy=5.5444 | logit_gap=0.0475 | max_prob=0.2554
# value=-6.735 target=-7.350
# entropy=5.5449 | logit_gap=0.0289 | max_prob=0.2537
# value=-6.723 target=-7.418
# entropy=5.5308 | logit_gap=0.2179 | max_prob=0.2841
# value=-6.860 target=-7.492
# entropy=5.5209 | logit_gap=0.2796 | max_prob=0.2932
# value=-7.388 target=-7.518
# entropy=5.5424 | logit_gap=0.0793 | max_prob=0.2599
# value=-7.537 target=-7.520
# entropy=5.5444 | logit_gap=0.0514 | max_prob=0.2551
# value=-7.097 target=-7.559
# entropy=5.5446 | logit_gap=0.0425 | max_prob=0.2555
# value=-7.233 target=-7.582
# entropy=5.5443 | logit_gap=0.0574 | max_prob=0.2567
# value=-6.953 target=-7.613
# entropy=5.5201 | logit_gap=0.2789 | max_prob=0.2944
# value=-7.532 target=-7.619
# entropy=5.5372 | logit_gap=0.1637 | max_prob=0.2675
# value=-7.296 target=-7.645
# entropy=5.5399 | logit_gap=0.1187 | max_prob=0.2645
# value=-7.583 target=-7.647
# entropy=5.5426 | logit_gap=0.0900 | max_prob=0.2598
# value=-7.732 target=-7.636
# entropy=5.5420 | logit_gap=0.0960 | max_prob=0.2618
# value=-7.136 target=-7.653
# entropy=5.5302 | logit_gap=0.2123 | max_prob=0.2803
# value=-7.419 target=-7.659
# entropy=5.5397 | logit_gap=0.1198 | max_prob=0.2649
# value=-7.846 target=-7.625
# entropy=5.5435 | logit_gap=0.0701 | max_prob=0.2590
# value=-7.658 target=-7.576
# entropy=5.5381 | logit_gap=0.1504 | max_prob=0.2655
# value=-7.779 target=-7.524
# entropy=5.5440 | logit_gap=0.0588 | max_prob=0.2602
# value=-7.229 target=-7.521
# entropy=5.5441 | logit_gap=0.0636 | max_prob=0.2564
# value=-6.857 target=-7.554
# entropy=5.5380 | logit_gap=0.1566 | max_prob=0.2747
# value=-7.167 target=-7.572
# entropy=5.5429 | logit_gap=0.0898 | max_prob=0.2623
# value=-7.188 target=-7.598
# entropy=5.5448 | logit_gap=0.0326 | max_prob=0.2537
# value=-7.218 target=-7.638
# entropy=5.5449 | logit_gap=0.0313 | max_prob=0.2539
# value=-7.343 target=-7.673
# entropy=5.5445 | logit_gap=0.0491 | max_prob=0.2553
# value=-7.125 target=-7.701
# entropy=5.5385 | logit_gap=0.1510 | max_prob=0.2724
# value=-7.545 target=-7.712
# entropy=5.5435 | logit_gap=0.0728 | max_prob=0.2564
# value=-7.699 target=-7.696
# entropy=5.5391 | logit_gap=0.1479 | max_prob=0.2701
# value=-7.535 target=-7.699
# entropy=5.5443 | logit_gap=0.0501 | max_prob=0.2565
# value=-7.604 target=-7.687
# entropy=5.5437 | logit_gap=0.0746 | max_prob=0.2584
# value=-8.126 target=-7.634
# entropy=5.5441 | logit_gap=0.0621 | max_prob=0.2568
# value=-7.184 target=-7.651
# entropy=5.5443 | logit_gap=0.0513 | max_prob=0.2557
# value=-7.483 target=-7.635
# entropy=5.5437 | logit_gap=0.0703 | max_prob=0.2567
# value=-8.086 target=-7.576
# entropy=5.5427 | logit_gap=0.0879 | max_prob=0.2620
# value=-7.994 target=-7.512
# entropy=5.5449 | logit_gap=0.0333 | max_prob=0.2539
# value=-7.568 target=-7.504
# entropy=5.5277 | logit_gap=0.2478 | max_prob=0.2869
# value=-7.240 target=-7.499
# entropy=5.5334 | logit_gap=0.1897 | max_prob=0.2812
# value=-7.458 target=-7.491
# entropy=5.5439 | logit_gap=0.0630 | max_prob=0.2588
# value=-7.472 target=-7.484
# entropy=5.5430 | logit_gap=0.0878 | max_prob=0.2589
# value=-7.733 target=-7.460
# entropy=5.5443 | logit_gap=0.0534 | max_prob=0.2565
# value=-7.711 target=-7.433
# entropy=5.5319 | logit_gap=0.2016 | max_prob=0.2831
# value=-7.276 target=-7.440
# entropy=5.5349 | logit_gap=0.1851 | max_prob=0.2758
# value=-7.412 target=-7.444
# entropy=5.5435 | logit_gap=0.0714 | max_prob=0.2584
# value=-7.577 target=-7.428
# entropy=5.5449 | logit_gap=0.0289 | max_prob=0.2530
# value=-7.448 target=-7.421
# entropy=5.5413 | logit_gap=0.1190 | max_prob=0.2642
# value=-7.505 target=-7.400
# entropy=5.5447 | logit_gap=0.0384 | max_prob=0.2551
# value=-7.157 target=-7.388
# entropy=5.5437 | logit_gap=0.0706 | max_prob=0.2573
# value=-7.710 target=-7.333
# entropy=5.5163 | logit_gap=0.2969 | max_prob=0.2985
# value=-7.730 target=-7.267
# entropy=5.5383 | logit_gap=0.1486 | max_prob=0.2643
# value=-7.460 target=-7.260
# entropy=5.5443 | logit_gap=0.0553 | max_prob=0.2571
# value=-6.867 target=-7.326
# entropy=5.5449 | logit_gap=0.0295 | max_prob=0.2545
# value=-7.039 target=-7.387
# entropy=5.5369 | logit_gap=0.1731 | max_prob=0.2748
# value=-7.175 target=-7.416
# entropy=5.5377 | logit_gap=0.1663 | max_prob=0.2703
# value=-7.229 target=-7.441
# entropy=5.5435 | logit_gap=0.0738 | max_prob=0.2576
# value=-6.833 target=-7.488
# entropy=5.5293 | logit_gap=0.2275 | max_prob=0.2845
# value=-7.318 target=-7.515
# entropy=5.5413 | logit_gap=0.0993 | max_prob=0.2628
# value=-7.427 target=-7.544
# entropy=5.5413 | logit_gap=0.1076 | max_prob=0.2671
# value=-7.352 target=-7.578
# entropy=5.5442 | logit_gap=0.0562 | max_prob=0.2594
# value=-7.232 target=-7.616
# entropy=5.5206 | logit_gap=0.2757 | max_prob=0.2940
# value=-7.450 target=-7.637
# entropy=5.5438 | logit_gap=0.0669 | max_prob=0.2605
# value=-7.401 target=-7.651
# entropy=5.5384 | logit_gap=0.1451 | max_prob=0.2686
# value=-7.659 target=-7.652
# entropy=5.5328 | logit_gap=0.2015 | max_prob=0.2719
# value=-7.457 target=-7.664
# entropy=5.5412 | logit_gap=0.1108 | max_prob=0.2637
# value=-7.518 target=-7.665
# entropy=5.5442 | logit_gap=0.0514 | max_prob=0.2562
# value=-6.742 target=-7.721
# entropy=5.5436 | logit_gap=0.0723 | max_prob=0.2577
# value=-7.156 target=-7.748
# entropy=5.5434 | logit_gap=0.0840 | max_prob=0.2595
# value=-7.618 target=-7.744
# entropy=5.5445 | logit_gap=0.0501 | max_prob=0.2578
# value=-7.513 target=-7.764
# entropy=5.5351 | logit_gap=0.1720 | max_prob=0.2792
# value=-7.638 target=-7.776
# entropy=5.5446 | logit_gap=0.0421 | max_prob=0.2541
# value=-7.091 target=-7.809
# entropy=5.5385 | logit_gap=0.1501 | max_prob=0.2713
# value=-7.931 target=-7.764
# entropy=5.5326 | logit_gap=0.2111 | max_prob=0.2784
# value=-7.520 target=-7.758
# entropy=5.5404 | logit_gap=0.1227 | max_prob=0.2679
# value=-7.508 target=-7.748
# entropy=5.5448 | logit_gap=0.0387 | max_prob=0.2556
# value=-7.654 target=-7.713
# entropy=5.5445 | logit_gap=0.0490 | max_prob=0.2567
# value=-7.555 target=-7.683
# entropy=5.5446 | logit_gap=0.0413 | max_prob=0.2542
# value=-7.317 target=-7.641
# entropy=5.5308 | logit_gap=0.2140 | max_prob=0.2825
# value=-7.618 target=-7.619
# entropy=5.5410 | logit_gap=0.1198 | max_prob=0.2633
# value=-7.843 target=-7.580
# entropy=5.5436 | logit_gap=0.0769 | max_prob=0.2585
# value=-7.742 target=-7.535
# entropy=5.5439 | logit_gap=0.0678 | max_prob=0.2578
# value=-8.186 target=-7.434
# entropy=5.5437 | logit_gap=0.0687 | max_prob=0.2584
# value=-6.963 target=-7.456
# entropy=5.5403 | logit_gap=0.1333 | max_prob=0.2642
# value=-7.236 target=-7.456
# entropy=5.5441 | logit_gap=0.0615 | max_prob=0.2596
# value=-7.149 target=-7.469
# entropy=5.5386 | logit_gap=0.1424 | max_prob=0.2722
# value=-7.816 target=-7.430
# entropy=5.5385 | logit_gap=0.1464 | max_prob=0.2653
# value=-7.668 target=-7.392
# entropy=5.5418 | logit_gap=0.0970 | max_prob=0.2625
# value=-7.550 target=-7.370
# entropy=5.5371 | logit_gap=0.1599 | max_prob=0.2743
# value=-7.330 target=-7.360
# entropy=5.5448 | logit_gap=0.0377 | max_prob=0.2542
# value=-7.335 target=-7.365
# entropy=5.5447 | logit_gap=0.0343 | max_prob=0.2541
# value=-7.291 target=-7.375
# entropy=5.5361 | logit_gap=0.1744 | max_prob=0.2758
# value=-7.229 target=-7.382
# entropy=5.5438 | logit_gap=0.0715 | max_prob=0.2601
# value=-7.043 target=-7.401
# entropy=5.5434 | logit_gap=0.0798 | max_prob=0.2584
# value=-6.880 target=-7.430
# entropy=5.5441 | logit_gap=0.0563 | max_prob=0.2554
# value=-7.208 target=-7.454
# entropy=5.5440 | logit_gap=0.0654 | max_prob=0.2565
# value=-7.089 target=-7.465
# entropy=5.5441 | logit_gap=0.0530 | max_prob=0.2566
# value=-7.393 target=-7.468
# entropy=5.5449 | logit_gap=0.0304 | max_prob=0.2541
# value=-7.117 target=-7.492
# entropy=5.5367 | logit_gap=0.1717 | max_prob=0.2757
# value=-7.107 target=-7.531
# entropy=5.5369 | logit_gap=0.1628 | max_prob=0.2693
# value=-7.465 target=-7.542
# entropy=5.5425 | logit_gap=0.0953 | max_prob=0.2609
# value=-7.175 target=-7.551
# entropy=5.5406 | logit_gap=0.1190 | max_prob=0.2678
# value=-7.710 target=-7.530
# entropy=5.5309 | logit_gap=0.2245 | max_prob=0.2811
# value=-7.191 target=-7.538
# entropy=5.5430 | logit_gap=0.0891 | max_prob=0.2611
# value=-7.608 target=-7.529
# entropy=5.5434 | logit_gap=0.0829 | max_prob=0.2594
# value=-6.861 target=-7.549
# entropy=5.5433 | logit_gap=0.0677 | max_prob=0.2583
# value=-7.734 target=-7.494
# entropy=5.5446 | logit_gap=0.0428 | max_prob=0.2565
# value=-7.189 target=-7.470
# entropy=5.5437 | logit_gap=0.0739 | max_prob=0.2579
# value=-7.067 target=-7.481
# entropy=5.5293 | logit_gap=0.2215 | max_prob=0.2866
# value=-7.375 target=-7.470
# entropy=5.5439 | logit_gap=0.0577 | max_prob=0.2578
# value=-7.671 target=-7.430
# entropy=5.5418 | logit_gap=0.1054 | max_prob=0.2593
# value=-7.809 target=-7.367
# entropy=5.5446 | logit_gap=0.0409 | max_prob=0.2537
# value=-7.299 target=-7.321
# entropy=5.5422 | logit_gap=0.0973 | max_prob=0.2593
# value=-7.701 target=-7.270
# entropy=5.5267 | logit_gap=0.2375 | max_prob=0.2888
# value=-7.720 target=-7.225
# entropy=5.5329 | logit_gap=0.1986 | max_prob=0.2716
# value=-7.532 target=-7.209
# entropy=5.5441 | logit_gap=0.0638 | max_prob=0.2579
# value=-7.105 target=-7.185
# entropy=5.5440 | logit_gap=0.0669 | max_prob=0.2573
# value=-7.150 target=-7.180
# entropy=5.5447 | logit_gap=0.0389 | max_prob=0.2550
# value=-7.134 target=-7.195
# entropy=5.5443 | logit_gap=0.0565 | max_prob=0.2564
# value=-7.409 target=-7.189
# entropy=5.5446 | logit_gap=0.0436 | max_prob=0.2540
# value=-7.455 target=-7.171
# entropy=5.5443 | logit_gap=0.0594 | max_prob=0.2570
# value=-7.417 target=-7.152
# entropy=5.5329 | logit_gap=0.2047 | max_prob=0.2801
# value=-7.300 target=-7.138
# entropy=5.5298 | logit_gap=0.2227 | max_prob=0.2826
# value=-7.509 target=-7.118
# entropy=5.5437 | logit_gap=0.0700 | max_prob=0.2601
# value=-7.767 target=-7.069
# entropy=5.5444 | logit_gap=0.0543 | max_prob=0.2562
# value=-7.034 target=-7.050
# entropy=5.5384 | logit_gap=0.1480 | max_prob=0.2707
# value=-7.831 target=-6.999
# entropy=5.5442 | logit_gap=0.0612 | max_prob=0.2585
# value=-7.737 target=-6.952
# entropy=5.5361 | logit_gap=0.1739 | max_prob=0.2753
# value=-7.520 target=-6.924
# entropy=5.5305 | logit_gap=0.2293 | max_prob=0.2781
# value=-7.285 target=-6.896
# entropy=5.5298 | logit_gap=0.2160 | max_prob=0.2809
# value=-7.107 target=-6.892
# entropy=5.5407 | logit_gap=0.1113 | max_prob=0.2629
# value=-7.268 target=-6.869
# entropy=5.5387 | logit_gap=0.1441 | max_prob=0.2643
# value=-7.489 target=-6.840
# entropy=5.5415 | logit_gap=0.0923 | max_prob=0.2613
# value=-7.685 target=-6.791
# entropy=5.5427 | logit_gap=0.0858 | max_prob=0.2598
# value=-7.740 target=-6.723
# entropy=5.5335 | logit_gap=0.1987 | max_prob=0.2732
# value=-7.578 target=-6.651
# entropy=5.5442 | logit_gap=0.0608 | max_prob=0.2572
# value=-7.148 target=-6.616
# entropy=5.5445 | logit_gap=0.0476 | max_prob=0.2557
# value=-6.913 target=-6.591
# entropy=5.5440 | logit_gap=0.0604 | max_prob=0.2593
# value=-6.709 target=-6.585
# entropy=5.5357 | logit_gap=0.1700 | max_prob=0.2780
# value=-7.381 target=-6.560
# entropy=5.5322 | logit_gap=0.2106 | max_prob=0.2807
# value=-7.090 target=-6.536
# entropy=5.5377 | logit_gap=0.1564 | max_prob=0.2702
# value=-7.602 target=-6.480
# entropy=5.5321 | logit_gap=0.2069 | max_prob=0.2709
# value=-7.276 target=-6.435
# critic_epoch=5 loss=0.2604 grad=3.0876
#
# encoder_grad : 2.2697
# actor_grad   : 3.4427
# critic_grad  : 3.0876
# ExplainedVar : -0.321
# Value mean   : -7.339
# Value std    : 0.106
# Return mean  : -7.301
# Return std   : 0.353
# TD mean      : 0.405
# TD max       : 1.802
#
#
# ======================================================================
# Reward      : -0.0764
# Actor Loss  : -0.0900
# Critic Loss : 0.2604
# Entropy     : 5.5401
# ExplainedVar: -0.321
# TD mean/max : 0.405 / 1.802
# ======================================================================
#
# <class 'marl_tsc.graph_based.models.graph_policy.GraphPolicy'>
# 782
# /content/drive/MyDrive/Uni-Masters/Group Project/outputs/graph_ctde.pt
# {'algorithm': 'graph_ctde', 'timestep': 200192, 'mean_training_reward': -0.07642578333616257, 'actor_loss': -0.09000349044799805, 'critic_loss': 0.2603759765625, 'total_loss': 0.14267192780971527}

# %%
fig, ax = plot_training_histories(history)
plt.show()

# %%
#history

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_training_history(history):

    actor_loss = [
        h["actor_loss"]
        for h in history
    ]

    critic_loss = [
        h["critic_loss"]
        for h in history
    ]

    total_loss = [
        h["total_loss"]
        for h in history
    ]

    reward = [
        h["mean_training_reward"]
        for h in history
    ]

    x = np.arange(len(history))

    fig, axes = plt.subplots(
        2,
        2,
        figsize=(14, 8),
    )

    #
    # Actor
    #

    axes[0, 0].plot(
        x,
        actor_loss,
    )
    axes[0, 0].set_title(
        "Actor Loss"
    )
    axes[0, 0].grid(True)

    #
    # Critic
    #

    axes[0, 1].plot(
        x,
        critic_loss,
    )
    axes[0, 1].set_title(
        "Critic Loss"
    )
    axes[0, 1].grid(True)

    #
    # Reward
    #

    axes[1, 0].plot(
        x,
        reward,
    )

    if len(reward) >= 10:

        rolling = np.convolve(
            reward,
            np.ones(10) / 10,
            mode="valid",
        )

        axes[1, 0].plot(
            np.arange(
                9,
                len(reward),
            ),
            rolling,
            linewidth=2,
        )

    axes[1, 0].set_title(
        "Mean Training Reward"
    )
    axes[1, 0].grid(True)

    #
    # Critic vs Actor
    #

    axes[1, 1].plot(
        x,
        critic_loss,
        label="critic",
    )

    axes[1, 1].plot(
        x,
        np.abs(actor_loss),
        label="|actor|",
    )

    axes[1, 1].set_title(
        "Loss Magnitude Comparison"
    )

    axes[1, 1].legend()
    axes[1, 1].grid(True)

    plt.tight_layout()
    plt.show()

    #
    # Useful summary stats
    #

    print(
        f"Final Actor Loss : {actor_loss[-1]:.6f}"
    )

    print(
        f"Final Critic Loss: {critic_loss[-1]:.6f}"
    )

    print(
        f"Best Critic Loss : {min(critic_loss):.6f}"
    )

    print(
        f"Mean Reward      : {np.mean(reward):.6f}"
    )

    print(
        f"Final Reward     : {reward[-1]:.6f}"
    )

# %%
plot_training_history(history)
# Out:
# Final Actor Loss : -0.090003
# Final Critic Loss: 0.260376
# Best Critic Loss : 0.097420
# Mean Reward      : -0.084512
# Final Reward     : -0.076426

# %%
def get_evaluation_results(policy):
    return evaluate_policy(
        config_file=paths.config_file,
        traffic_light_ids=traffic_light_ids,
        policy=policy,
        episodes=EVALUATION_EPISODES,
        max_steps=EPISODE_STEPS,
        seed=42,
        env_kwargs={
            "green_phase_count": GREEN_PHASE_COUNT,
            "min_green_seconds": MIN_GREEN_SECONDS,
            "seconds_per_action": SECONDS_PER_ACTION,
            "switch_penalty": SWITCH_PENALTY,
            "global_metric_interval": 10,
        },
    )

# %%
from marl_tsc.graph_based.graph_policy_adapter import (
    GraphPolicyAdapter,
)

graph_policy = GraphPolicyAdapter(
    graph_policy=model,
    topology=topology,
    policy_name="graph_ctde",
)

results = get_evaluation_results(
    graph_policy
)

print(results)
# Out:
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# /content/marl-tsc/src/marl_tsc/graph_based/graph_policy_adapter.py:35: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   x = torch.tensor(
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Finished Evaluation Episode 1/3 - Total Reward: -368.52
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# ...
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Finished Evaluation Episode 3/3 - Total Reward: -358.80
# {'policy_name': 'graph_ctde', 'episodes': 3, 'mean_total_reward': -361.8233333333332, 'mean_local_queue': 0.9748437500000001, 'mean_max_queue': 9.666666666666666, 'total_completed_steps': 1800, 'mean_switches_per_episode': 1171.6666666666667, 'mean_arrived_vehicles_per_episode': 1436.0, 'mean_waiting_time': 28.893518400635838, 'mean_total_time_loss': 4049.719494918536, 'mean_vehicle_count': 53.12222222222223}

# %%
from pprint import pprint
from marl_tsc.graph_based.graph_policy_adapter import GraphPolicyAdapter

results = get_evaluation_results(
    GraphPolicyAdapter(model,topology)
)

pprint(results)
# Out:
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Finished Evaluation Episode 1/3 - Total Reward: -368.52
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# ...
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Finished Evaluation Episode 3/3 - Total Reward: -358.80
# {'episodes': 3,
#  'mean_arrived_vehicles_per_episode': 1436.0,
#  'mean_local_queue': 0.9748437500000001,
#  'mean_max_queue': 9.666666666666666,
#  'mean_switches_per_episode': 1171.6666666666667,
#  'mean_total_reward': -361.8233333333332,
#  'mean_total_time_loss': 4049.719494918536,
#  'mean_vehicle_count': 53.12222222222223,
#  'mean_waiting_time': 28.893518400635838,
#  'policy_name': 'GraphPolicyAdapter',
#  'total_completed_steps': 1800}

# %% [markdown]
# ### Graph-mappo

# %%
from marl_tsc.graph_based.train_graph_mappo import train_graph_mappo

map_gat_model, map_gat_history, map_cat_model_path = train_graph_mappo(
    config_file=paths.config_file,
    network_file=paths.network_file,
    traffic_light_ids=["B1", "B2", "C1", "C2"],
    output_dir=OUTPUT_DIR,
    total_timesteps=200_000,
    clip_ratio=0.2,
    entropy_coef=0.01,
    update_epochs=3,
)
# Out:
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Iter  10 | Actor 0.0887 | Critic 0.6677
#  Retrying in 1 seconds
# Iter  20 | Actor 0.0690 | Critic 0.2286
#  Retrying in 1 seconds
# Iter  30 | Actor 0.0259 | Critic 0.2235
#  Retrying in 1 seconds
# Iter  40 | Actor -0.0049 | Critic 0.2402
#  Retrying in 1 seconds
# Iter  50 | Actor 0.0082 | Critic 0.1578
# Iter  60 | Actor -0.0049 | Critic 0.2168
#  Retrying in 1 seconds
# Iter  70 | Actor -0.0022 | Critic 0.3187
#  Retrying in 1 seconds
# Iter  80 | Actor -0.0040 | Critic 0.1049
#  Retrying in 1 seconds
# Iter  90 | Actor 0.0056 | Critic 0.1502
#  Retrying in 1 seconds
# Iter 100 | Actor 0.0181 | Critic 0.2234
#  Retrying in 1 seconds
# Iter 110 | Actor 0.0176 | Critic 0.0891
# Iter 120 | Actor 0.0092 | Critic 0.2152
#  Retrying in 1 seconds
# Iter 130 | Actor 0.0110 | Critic 0.5801
#  Retrying in 1 seconds
# Iter 140 | Actor 0.0037 | Critic 0.1965
#  Retrying in 1 seconds
# Iter 150 | Actor -0.0049 | Critic 1.3739
#  Retrying in 1 seconds
# Iter 160 | Actor -0.0079 | Critic 0.0704
#  Retrying in 1 seconds
# Iter 170 | Actor 0.0110 | Critic 4.2737
# Iter 180 | Actor -0.0233 | Critic 0.1630
#  Retrying in 1 seconds
# Iter 190 | Actor -0.0032 | Critic 0.2770
#  Retrying in 1 seconds
# Iter 200 | Actor -0.0064 | Critic 0.1941
#  Retrying in 1 seconds
# Iter 210 | Actor -0.0047 | Critic 0.7412
#  Retrying in 1 seconds
# Iter 220 | Actor -0.0060 | Critic 0.2166
#  Retrying in 1 seconds
# Iter 230 | Actor 0.0107 | Critic 4.6356
# Iter 240 | Actor 0.0018 | Critic 0.3104
#  Retrying in 1 seconds
# Iter 250 | Actor -0.0063 | Critic 0.0497
#  Retrying in 1 seconds
# Iter 260 | Actor -0.0023 | Critic 0.2355
#  Retrying in 1 seconds
# Iter 270 | Actor -0.0056 | Critic 0.6917
#  Retrying in 1 seconds
# Iter 280 | Actor -0.0169 | Critic 0.5482
#  Retrying in 1 seconds
# Iter 290 | Actor -0.0017 | Critic 3.6332
# Iter 300 | Actor 0.0099 | Critic 0.1048
#  Retrying in 1 seconds
# Iter 310 | Actor -0.0074 | Critic 0.4312
#  Retrying in 1 seconds
# Iter 320 | Actor 0.0095 | Critic 0.0525
#  Retrying in 1 seconds
# Iter 330 | Actor 0.0281 | Critic 0.0559
#  Retrying in 1 seconds
# Iter 340 | Actor 0.0040 | Critic 0.1186
# Iter 350 | Actor -0.0143 | Critic 0.0607
#  Retrying in 1 seconds
# Iter 360 | Actor 0.0004 | Critic 0.1764
#  Retrying in 1 seconds
# Iter 370 | Actor -0.0089 | Critic 0.1309
#  Retrying in 1 seconds
# Iter 380 | Actor -0.0037 | Critic 0.1835
#  Retrying in 1 seconds
# Iter 390 | Actor 0.0016 | Critic 0.2406
#  Retrying in 1 seconds
# Iter 400 | Actor -0.0098 | Critic 4.2000
# Iter 410 | Actor -0.0108 | Critic 0.3730
#  Retrying in 1 seconds
# Iter 420 | Actor -0.0160 | Critic 0.3492
#  Retrying in 1 seconds
# Iter 430 | Actor 0.0016 | Critic 0.1946
#  Retrying in 1 seconds
# Iter 440 | Actor 0.0085 | Critic 0.1883
#  Retrying in 1 seconds
# Iter 450 | Actor 0.0033 | Critic 0.1820
#  Retrying in 1 seconds
# Iter 460 | Actor -0.0128 | Critic 6.1249
# Iter 470 | Actor 0.0028 | Critic 0.1753
#  Retrying in 1 seconds
# Iter 480 | Actor 0.0088 | Critic 0.1222
#  Retrying in 1 seconds
# Iter 490 | Actor 0.0102 | Critic 0.0675
#  Retrying in 1 seconds
# Iter 500 | Actor 0.0027 | Critic 0.1345
#  Retrying in 1 seconds
# Iter 510 | Actor 0.0173 | Critic 0.1441
#  Retrying in 1 seconds
# Iter 520 | Actor 0.0366 | Critic 3.9365
# Iter 530 | Actor 0.0230 | Critic 0.0699
#  Retrying in 1 seconds
# Iter 540 | Actor -0.0058 | Critic 0.2262
#  Retrying in 1 seconds
# Iter 550 | Actor 0.0006 | Critic 0.1603
#  Retrying in 1 seconds
# Iter 560 | Actor -0.0080 | Critic 0.4393
#  Retrying in 1 seconds
# Iter 570 | Actor 0.0033 | Critic 0.1149
# Iter 580 | Actor -0.0127 | Critic 0.1243
#  Retrying in 1 seconds
# Iter 590 | Actor -0.0022 | Critic 0.1934
#  Retrying in 1 seconds
# Iter 600 | Actor -0.0108 | Critic 0.1051
#  Retrying in 1 seconds
# Iter 610 | Actor -0.0113 | Critic 0.8309
#  Retrying in 1 seconds
# Iter 620 | Actor 0.0267 | Critic 0.1017
# Iter 630 | Actor -0.0172 | Critic 0.0440
#  Retrying in 1 seconds
# Iter 640 | Actor -0.0011 | Critic 0.1004
#  Retrying in 1 seconds
# Iter 650 | Actor -0.0051 | Critic 0.0821
#  Retrying in 1 seconds
# Iter 660 | Actor -0.0003 | Critic 0.1211
#  Retrying in 1 seconds
# Iter 670 | Actor 0.0066 | Critic 0.0447
#  Retrying in 1 seconds
# Iter 680 | Actor 0.0033 | Critic 0.1495
# Iter 690 | Actor 0.0038 | Critic 0.0885
#  Retrying in 1 seconds
# Iter 700 | Actor -0.0002 | Critic 0.1055
#  Retrying in 1 seconds
# Iter 710 | Actor 0.0127 | Critic 0.1093
#  Retrying in 1 seconds
# Iter 720 | Actor 0.0012 | Critic 0.1128
#  Retrying in 1 seconds
# Iter 730 | Actor -0.0049 | Critic 0.0662
#  Retrying in 1 seconds
# Iter 740 | Actor 0.0258 | Critic 0.1904
# Iter 750 | Actor -0.0108 | Critic 0.1703
#  Retrying in 1 seconds
# Iter 760 | Actor 0.0149 | Critic 0.0805
#  Retrying in 1 seconds
# Iter 770 | Actor 0.0129 | Critic 0.0785
#  Retrying in 1 seconds
# Iter 780 | Actor 0.0015 | Critic 0.0348
#  Retrying in 1 seconds
# Iter 790 | Actor 0.0043 | Critic 0.1083
#  Retrying in 1 seconds
# Iter 800 | Actor 0.0501 | Critic 0.1059
# Iter 810 | Actor 0.0111 | Critic 0.0731
#  Retrying in 1 seconds
# Iter 820 | Actor -0.0016 | Critic 0.1515
#  Retrying in 1 seconds
# Iter 830 | Actor 0.0034 | Critic 0.1138
#  Retrying in 1 seconds
# Iter 840 | Actor 0.0083 | Critic 0.1116
#  Retrying in 1 seconds
# Iter 850 | Actor -0.0028 | Critic 0.5216
#  Retrying in 1 seconds
# Iter 860 | Actor 0.0207 | Critic 3.7474
# Iter 870 | Actor 0.0106 | Critic 0.0415
#  Retrying in 1 seconds
# Iter 880 | Actor 0.0168 | Critic 0.0984
#  Retrying in 1 seconds
# Iter 890 | Actor 0.0070 | Critic 0.2235
#  Retrying in 1 seconds
# Iter 900 | Actor 0.0061 | Critic 0.2879
#  Retrying in 1 seconds
# Iter 910 | Actor 0.0157 | Critic 0.1400
#  Retrying in 1 seconds
# Iter 920 | Actor 0.0050 | Critic 4.9399
# Iter 930 | Actor -0.0144 | Critic 0.0611
#  Retrying in 1 seconds
# Iter 940 | Actor -0.0126 | Critic 0.1518
#  Retrying in 1 seconds
# Iter 950 | Actor -0.0297 | Critic 0.6135
#  Retrying in 1 seconds
# Iter 960 | Actor 0.0108 | Critic 0.0930
#  Retrying in 1 seconds
# Iter 970 | Actor 0.0140 | Critic 0.0763
#  Retrying in 1 seconds
# Iter 980 | Actor 0.0130 | Critic 4.0322
# Iter 990 | Actor 0.0009 | Critic 0.0596
#  Retrying in 1 seconds
# Iter 1000 | Actor 0.0040 | Critic 0.0550
#  Retrying in 1 seconds
# Iter 1010 | Actor 0.0092 | Critic 0.0794
#  Retrying in 1 seconds
# Iter 1020 | Actor 0.0247 | Critic 0.1712
#  Retrying in 1 seconds
# Iter 1030 | Actor 0.0235 | Critic 0.0504
#  Retrying in 1 seconds
# Iter 1040 | Actor -0.0136 | Critic 4.6679
# Iter 1050 | Actor 0.0110 | Critic 0.0541
#  Retrying in 1 seconds
# Iter 1060 | Actor 0.0001 | Critic 0.0380
#  Retrying in 1 seconds
# Iter 1070 | Actor -0.0049 | Critic 0.0395
#  Retrying in 1 seconds
# Iter 1080 | Actor 0.0096 | Critic 0.1441
#  Retrying in 1 seconds
# Iter 1090 | Actor 0.0263 | Critic 0.2828
#  Retrying in 1 seconds
# Iter 1100 | Actor -0.0054 | Critic 3.1375
# Iter 1110 | Actor 0.0076 | Critic 0.0615
#  Retrying in 1 seconds
# Iter 1120 | Actor -0.0103 | Critic 0.0505
#  Retrying in 1 seconds
# Iter 1130 | Actor 0.0287 | Critic 0.0653
#  Retrying in 1 seconds
# Iter 1140 | Actor -0.0183 | Critic 0.1531
#  Retrying in 1 seconds
# Iter 1150 | Actor -0.0057 | Critic 0.0908
# Iter 1160 | Actor -0.0147 | Critic 0.1168
#  Retrying in 1 seconds
# Iter 1170 | Actor 0.0047 | Critic 0.0531
#  Retrying in 1 seconds
# Iter 1180 | Actor 0.0084 | Critic 0.0492
#  Retrying in 1 seconds
# Iter 1190 | Actor -0.0058 | Critic 0.0614
#  Retrying in 1 seconds
# Iter 1200 | Actor 0.0052 | Critic 0.0347
#  Retrying in 1 seconds
# Iter 1210 | Actor 0.0005 | Critic 6.6929
# Iter 1220 | Actor 0.0142 | Critic 0.0694
#  Retrying in 1 seconds
# Iter 1230 | Actor -0.0023 | Critic 0.0703
#  Retrying in 1 seconds
# Iter 1240 | Actor 0.0258 | Critic 0.0825
#  Retrying in 1 seconds
# Iter 1250 | Actor 0.0054 | Critic 0.1844
#  Retrying in 1 seconds
# Iter 1260 | Actor 0.0275 | Critic 0.0588
#  Retrying in 1 seconds
# Iter 1270 | Actor -0.0132 | Critic 2.4608
# Iter 1280 | Actor 0.0006 | Critic 0.1110
#  Retrying in 1 seconds
# Iter 1290 | Actor 0.0060 | Critic 0.3394
#  Retrying in 1 seconds
# Iter 1300 | Actor -0.0028 | Critic 0.0594
#  Retrying in 1 seconds
# Iter 1310 | Actor 0.0006 | Critic 0.2048
#  Retrying in 1 seconds
# Iter 1320 | Actor 0.0067 | Critic 0.0836
# Iter 1330 | Actor -0.0049 | Critic 0.1392
#  Retrying in 1 seconds
# Iter 1340 | Actor 0.0070 | Critic 0.0443
#  Retrying in 1 seconds
# Iter 1350 | Actor -0.0078 | Critic 0.0490
#  Retrying in 1 seconds
# Iter 1360 | Actor 0.0057 | Critic 0.0337
#  Retrying in 1 seconds
# Iter 1370 | Actor 0.0006 | Critic 0.0630
#  Retrying in 1 seconds
# Iter 1380 | Actor 0.0208 | Critic 0.5553
# Iter 1390 | Actor 0.0317 | Critic 0.0429
#  Retrying in 1 seconds
# Iter 1400 | Actor 0.0186 | Critic 0.0257
#  Retrying in 1 seconds
# Iter 1410 | Actor 0.0031 | Critic 0.0281
#  Retrying in 1 seconds
# Iter 1420 | Actor 0.0085 | Critic 0.0512
#  Retrying in 1 seconds
# Iter 1430 | Actor 0.0237 | Critic 0.0364
#  Retrying in 1 seconds
# Iter 1440 | Actor 0.0153 | Critic 0.2872
# Iter 1450 | Actor -0.0012 | Critic 0.0872
#  Retrying in 1 seconds
# Iter 1460 | Actor -0.0106 | Critic 0.1122
#  Retrying in 1 seconds
# Iter 1470 | Actor -0.0071 | Critic 0.0350
#  Retrying in 1 seconds
# Iter 1480 | Actor -0.0027 | Critic 0.0797
#  Retrying in 1 seconds
# Iter 1490 | Actor 0.0013 | Critic 0.0499
#  Retrying in 1 seconds
# Iter 1500 | Actor 0.0370 | Critic 0.2433
# Iter 1510 | Actor -0.0009 | Critic 0.0310
#  Retrying in 1 seconds
# Iter 1520 | Actor -0.0012 | Critic 0.1409
#  Retrying in 1 seconds
# Iter 1530 | Actor 0.0118 | Critic 0.0259
#  Retrying in 1 seconds
# Iter 1540 | Actor -0.0055 | Critic 0.0822
#  Retrying in 1 seconds
# Iter 1550 | Actor 0.0055 | Critic 0.0425
#  Retrying in 1 seconds
# Iter 1560 | Actor 0.0169 | Critic 0.1804
# Checkpoint saved: /content/drive/MyDrive/Uni-Masters/Group Project/outputs/models/graph_mappo_99968.pt
# Iter 1570 | Actor 0.0230 | Critic 0.0535
#  Retrying in 1 seconds
# Iter 1580 | Actor 0.0264 | Critic 0.0427
#  Retrying in 1 seconds
# Iter 1590 | Actor 0.0096 | Critic 0.0688
#  Retrying in 1 seconds
# Iter 1600 | Actor 0.0079 | Critic 0.0324
#  Retrying in 1 seconds
# Iter 1610 | Actor -0.0016 | Critic 0.0387
#  Retrying in 1 seconds
# Iter 1620 | Actor 0.0056 | Critic 3.0817
# Iter 1630 | Actor 0.0010 | Critic 0.0459
#  Retrying in 1 seconds
# Iter 1640 | Actor -0.0135 | Critic 0.3134
#  Retrying in 1 seconds
# Iter 1650 | Actor -0.0018 | Critic 0.0484
#  Retrying in 1 seconds
# Iter 1660 | Actor 0.0057 | Critic 0.0184
#  Retrying in 1 seconds
# Iter 1670 | Actor 0.0040 | Critic 4.7338
# Iter 1680 | Actor -0.0040 | Critic 0.0296
#  Retrying in 1 seconds
# Iter 1690 | Actor 0.0371 | Critic 0.0630
#  Retrying in 1 seconds
# Iter 1700 | Actor -0.0078 | Critic 0.0261
#  Retrying in 1 seconds
# Iter 1710 | Actor 0.0150 | Critic 0.0972
#  Retrying in 1 seconds
# Iter 1720 | Actor 0.0203 | Critic 0.0839
#  Retrying in 1 seconds
# Iter 1730 | Actor 0.0087 | Critic 3.6863
# Iter 1740 | Actor 0.0314 | Critic 0.0336
#  Retrying in 1 seconds
# Iter 1750 | Actor 0.0038 | Critic 0.0578
#  Retrying in 1 seconds
# Iter 1760 | Actor -0.0090 | Critic 0.0438
#  Retrying in 1 seconds
# Iter 1770 | Actor -0.0114 | Critic 0.0412
#  Retrying in 1 seconds
# Iter 1780 | Actor 0.0224 | Critic 0.2908
# Iter 1790 | Actor 0.0067 | Critic 0.0442
#  Retrying in 1 seconds
# Iter 1800 | Actor -0.0013 | Critic 0.0201
#  Retrying in 1 seconds
# Iter 1810 | Actor -0.0132 | Critic 0.0309
#  Retrying in 1 seconds
# Iter 1820 | Actor 0.0051 | Critic 0.0358
#  Retrying in 1 seconds
# Iter 1830 | Actor 0.0165 | Critic 0.0230
#  Retrying in 1 seconds
# Iter 1840 | Actor 0.0142 | Critic 0.1545
# Iter 1850 | Actor 0.0078 | Critic 0.0437
#  Retrying in 1 seconds
# Iter 1860 | Actor 0.0176 | Critic 0.0421
#  Retrying in 1 seconds
# Iter 1870 | Actor -0.0064 | Critic 0.0530
#  Retrying in 1 seconds
# Iter 1880 | Actor -0.0005 | Critic 0.0518
#  Retrying in 1 seconds
# Iter 1890 | Actor 0.0106 | Critic 0.0603
#  Retrying in 1 seconds
# Iter 1900 | Actor 0.0088 | Critic 25.8422
# Iter 1910 | Actor 0.0180 | Critic 0.0575
#  Retrying in 1 seconds
# Iter 1920 | Actor 0.0239 | Critic 0.0398
#  Retrying in 1 seconds
# Iter 1930 | Actor -0.0016 | Critic 0.0780
#  Retrying in 1 seconds
# Iter 1940 | Actor 0.0131 | Critic 0.0858
#  Retrying in 1 seconds
# Iter 1950 | Actor 0.0010 | Critic 0.1093
#  Retrying in 1 seconds
# Iter 1960 | Actor 0.0150 | Critic 3.7580
# Iter 1970 | Actor -0.0081 | Critic 0.0637
#  Retrying in 1 seconds
# Iter 1980 | Actor -0.0092 | Critic 0.0930
#  Retrying in 1 seconds
# Iter 1990 | Actor 0.0122 | Critic 0.0366
#  Retrying in 1 seconds
# Iter 2000 | Actor 0.0023 | Critic 0.1286
#  Retrying in 1 seconds
# Iter 2010 | Actor 0.0068 | Critic 0.0513
#  Retrying in 1 seconds
# Iter 2020 | Actor -0.0102 | Critic 1.3881
# Iter 2030 | Actor -0.0108 | Critic 0.0434
#  Retrying in 1 seconds
# Iter 2040 | Actor 0.0010 | Critic 0.0539
#  Retrying in 1 seconds
# Iter 2050 | Actor 0.0107 | Critic 0.0299
#  Retrying in 1 seconds
# Iter 2060 | Actor 0.0212 | Critic 0.1020
#  Retrying in 1 seconds
# Iter 2070 | Actor -0.0033 | Critic 0.0463
#  Retrying in 1 seconds
# Iter 2080 | Actor 0.0238 | Critic 4.2705
# Iter 2090 | Actor 0.0129 | Critic 0.0345
#  Retrying in 1 seconds
# Iter 2100 | Actor -0.0131 | Critic 0.0570
#  Retrying in 1 seconds
# Iter 2110 | Actor 0.0170 | Critic 0.0321
#  Retrying in 1 seconds
# Iter 2120 | Actor 0.0123 | Critic 0.0774
#  Retrying in 1 seconds
# Iter 2130 | Actor -0.0051 | Critic 0.1184
#  Retrying in 1 seconds
# Iter 2140 | Actor 0.0329 | Critic 2.4310
# Iter 2150 | Actor 0.0043 | Critic 0.0607
#  Retrying in 1 seconds
# Iter 2160 | Actor -0.0025 | Critic 0.0785
#  Retrying in 1 seconds
# Iter 2170 | Actor 0.0081 | Critic 0.0648
#  Retrying in 1 seconds
# Iter 2180 | Actor -0.0078 | Critic 0.0646
#  Retrying in 1 seconds
# Iter 2190 | Actor -0.0156 | Critic 0.0562
#  Retrying in 1 seconds
# Iter 2200 | Actor 0.0290 | Critic 1.8684
# Iter 2210 | Actor 0.0225 | Critic 0.0616
#  Retrying in 1 seconds
# Iter 2220 | Actor 0.0026 | Critic 0.0277
#  Retrying in 1 seconds
# Iter 2230 | Actor 0.0008 | Critic 0.0356
#  Retrying in 1 seconds
# Iter 2240 | Actor 0.0190 | Critic 0.0771
#  Retrying in 1 seconds
# Iter 2250 | Actor 0.0093 | Critic 0.1270
#  Retrying in 1 seconds
# Iter 2260 | Actor 0.0064 | Critic 2.4485
# Iter 2270 | Actor -0.0007 | Critic 0.0347
#  Retrying in 1 seconds
# Iter 2280 | Actor -0.0088 | Critic 0.0412
#  Retrying in 1 seconds
# Iter 2290 | Actor -0.0043 | Critic 0.0413
#  Retrying in 1 seconds
# Iter 2300 | Actor 0.0068 | Critic 0.0757
#  Retrying in 1 seconds
# Iter 2310 | Actor -0.0095 | Critic 0.0989
#  Retrying in 1 seconds
# Iter 2320 | Actor 0.0216 | Critic 1.9523
# Iter 2330 | Actor 0.0005 | Critic 0.0454
#  Retrying in 1 seconds
# Iter 2340 | Actor 0.0050 | Critic 0.0443
#  Retrying in 1 seconds
# Iter 2350 | Actor 0.0049 | Critic 0.0332
#  Retrying in 1 seconds
# Iter 2360 | Actor -0.0050 | Critic 0.0589
#  Retrying in 1 seconds
# Iter 2370 | Actor 0.0034 | Critic 0.0980
#  Retrying in 1 seconds
# Iter 2380 | Actor 0.0255 | Critic 2.2327
# Iter 2390 | Actor -0.0071 | Critic 0.0259
#  Retrying in 1 seconds
# Iter 2400 | Actor 0.0217 | Critic 0.0383
#  Retrying in 1 seconds
# Iter 2410 | Actor 0.0005 | Critic 0.0143
#  Retrying in 1 seconds
# Iter 2420 | Actor 0.0005 | Critic 0.1294
#  Retrying in 1 seconds
# Iter 2430 | Actor -0.0064 | Critic 0.0461
#  Retrying in 1 seconds
# Iter 2440 | Actor 0.0236 | Critic 1.6330
# Iter 2450 | Actor -0.0036 | Critic 0.1024
#  Retrying in 1 seconds
# Iter 2460 | Actor -0.0031 | Critic 0.0259
#  Retrying in 1 seconds
# Iter 2470 | Actor -0.0072 | Critic 0.0354
#  Retrying in 1 seconds
# Iter 2480 | Actor 0.0025 | Critic 0.0512
#  Retrying in 1 seconds
# Iter 2490 | Actor -0.0138 | Critic 0.2173
# Iter 2500 | Actor 0.0107 | Critic 0.0278
#  Retrying in 1 seconds
# Iter 2510 | Actor 0.0292 | Critic 0.0333
#  Retrying in 1 seconds
# Iter 2520 | Actor 0.0038 | Critic 0.0342
#  Retrying in 1 seconds
# Iter 2530 | Actor 0.0319 | Critic 0.0245
#  Retrying in 1 seconds
# Iter 2540 | Actor -0.0102 | Critic 0.0240
#  Retrying in 1 seconds
# Iter 2550 | Actor 0.0195 | Critic 0.3068
# Iter 2560 | Actor 0.0032 | Critic 0.0322
#  Retrying in 1 seconds
# Iter 2570 | Actor 0.0262 | Critic 0.0477
#  Retrying in 1 seconds
# Iter 2580 | Actor -0.0066 | Critic 0.0384
#  Retrying in 1 seconds
# Iter 2590 | Actor 0.0061 | Critic 0.0517
#  Retrying in 1 seconds
# Iter 2600 | Actor -0.0004 | Critic 0.0238
#  Retrying in 1 seconds
# Iter 2610 | Actor -0.0106 | Critic 0.4568
# Iter 2620 | Actor 0.0052 | Critic 0.0179
#  Retrying in 1 seconds
# Iter 2630 | Actor 0.0044 | Critic 0.0421
#  Retrying in 1 seconds
# Iter 2640 | Actor -0.0083 | Critic 0.0303
#  Retrying in 1 seconds
# Iter 2650 | Actor 0.0017 | Critic 0.0340
#  Retrying in 1 seconds
# Iter 2660 | Actor -0.0157 | Critic 0.0562
#  Retrying in 1 seconds
# Iter 2670 | Actor 0.0122 | Critic 0.2935
# Iter 2680 | Actor 0.0051 | Critic 0.0243
#  Retrying in 1 seconds
# Iter 2690 | Actor 0.0189 | Critic 0.0424
#  Retrying in 1 seconds
# Iter 2700 | Actor -0.0101 | Critic 0.0419
#  Retrying in 1 seconds
# Iter 2710 | Actor 0.0078 | Critic 0.0203
#  Retrying in 1 seconds
# Iter 2720 | Actor 0.0097 | Critic 0.0511
#  Retrying in 1 seconds
# Iter 2730 | Actor 0.0166 | Critic 0.3219
# Iter 2740 | Actor 0.0045 | Critic 0.0183
#  Retrying in 1 seconds
# Iter 2750 | Actor 0.0284 | Critic 0.0350
#  Retrying in 1 seconds
# Iter 2760 | Actor 0.0040 | Critic 0.0225
#  Retrying in 1 seconds
# Iter 2770 | Actor 0.0067 | Critic 0.0272
#  Retrying in 1 seconds
# Iter 2780 | Actor -0.0132 | Critic 0.0255
#  Retrying in 1 seconds
# Iter 2790 | Actor -0.0079 | Critic 0.1917
# Iter 2800 | Actor -0.0067 | Critic 0.0166
#  Retrying in 1 seconds
# Iter 2810 | Actor 0.0009 | Critic 0.0323
#  Retrying in 1 seconds
# Iter 2820 | Actor 0.0062 | Critic 0.0605
#  Retrying in 1 seconds
# Iter 2830 | Actor -0.0029 | Critic 0.0384
#  Retrying in 1 seconds
# Iter 2840 | Actor -0.0091 | Critic 0.0350
#  Retrying in 1 seconds
# Iter 2850 | Actor -0.0098 | Critic 0.2834
# Iter 2860 | Actor 0.0088 | Critic 0.0295
#  Retrying in 1 seconds
# Iter 2870 | Actor 0.0242 | Critic 0.0437
#  Retrying in 1 seconds
# Iter 2880 | Actor -0.0038 | Critic 0.0353
#  Retrying in 1 seconds
# Iter 2890 | Actor 0.0068 | Critic 0.0237
#  Retrying in 1 seconds
# Iter 2900 | Actor 0.0079 | Critic 0.0501
#  Retrying in 1 seconds
# Iter 2910 | Actor -0.0184 | Critic 0.0922
# Iter 2920 | Actor -0.0005 | Critic 0.0215
#  Retrying in 1 seconds
# Iter 2930 | Actor 0.0055 | Critic 0.0245
#  Retrying in 1 seconds
# Iter 2940 | Actor 0.0292 | Critic 0.0429
#  Retrying in 1 seconds
# Iter 2950 | Actor -0.0042 | Critic 0.0576
#  Retrying in 1 seconds
# Iter 2960 | Actor -0.0096 | Critic 0.0293
#  Retrying in 1 seconds
# Iter 2970 | Actor 0.0375 | Critic 0.3909
# Iter 2980 | Actor 0.0242 | Critic 0.0176
#  Retrying in 1 seconds
# Iter 2990 | Actor -0.0079 | Critic 0.0653
#  Retrying in 1 seconds
# Iter 3000 | Actor 0.0111 | Critic 0.0275
#  Retrying in 1 seconds
# Iter 3010 | Actor -0.0067 | Critic 0.0399
#  Retrying in 1 seconds
# Iter 3020 | Actor -0.0064 | Critic 0.0289
#  Retrying in 1 seconds
# Iter 3030 | Actor -0.0072 | Critic 0.1839
# Iter 3040 | Actor 0.0072 | Critic 0.0300
#  Retrying in 1 seconds
# Iter 3050 | Actor 0.0139 | Critic 0.0323
#  Retrying in 1 seconds
# Iter 3060 | Actor -0.0033 | Critic 0.0235
#  Retrying in 1 seconds
# Iter 3070 | Actor 0.0134 | Critic 0.0122
#  Retrying in 1 seconds
# Iter 3080 | Actor 0.0069 | Critic 0.0396
#  Retrying in 1 seconds
# Iter 3090 | Actor 0.0212 | Critic 0.2685
# Iter 3100 | Actor 0.0076 | Critic 0.0355
#  Retrying in 1 seconds
# Iter 3110 | Actor 0.0037 | Critic 0.0244
#  Retrying in 1 seconds
# Iter 3120 | Actor 0.0045 | Critic 0.0489
# Checkpoint saved: /content/drive/MyDrive/Uni-Masters/Group Project/outputs/models/graph_mappo_199936.pt
#  Retrying in 1 seconds

# %%
plot_training_history(map_gat_history)
# Out:
# Final Actor Loss : 0.013443
# Final Critic Loss: 4.458825
# Best Critic Loss : 0.011516
# Mean Reward      : -0.067513
# Final Reward     : -0.046744

# %%
graph_mappo_policy = GraphPolicyAdapter(
    graph_policy= map_gat_model ,
    topology=topology,
    policy_name="graph_mappo",
)

mappo_eval = get_evaluation_results(
    graph_mappo_policy
)

print(mappo_eval)
# Out:
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 3, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Finished Evaluation Episode 1/3 - Total Reward: -116.76
#  Retrying in 1 seconds
#  Retrying in 1 seconds
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 2, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 1}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 3, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 3, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 2, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 1, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# ...
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 0, 'C2': 1}
# Actions: {'B1': 0, 'B2': 3, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 2, 'C2': 0}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 0, 'C2': 3}
# Actions: {'B1': 1, 'B2': 2, 'C1': 1, 'C2': 2}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 0, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 2, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 2}
# Actions: {'B1': 2, 'B2': 3, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 0, 'B2': 2, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 0, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 1, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 0}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 0, 'C2': 2}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 1, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 1, 'B2': 1, 'C1': 1, 'C2': 1}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 3, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 2, 'B2': 2, 'C1': 2, 'C2': 2}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 1, 'B2': 3, 'C1': 3, 'C2': 3}
# Actions: {'B1': 0, 'B2': 0, 'C1': 0, 'C2': 0}
# Finished Evaluation Episode 3/3 - Total Reward: -118.50
# {'policy_name': 'graph_mappo', 'episodes': 3, 'mean_total_reward': -118.85666666666668, 'mean_local_queue': 0.2938368055555556, 'mean_max_queue': 5.333333333333333, 'total_completed_steps': 1800, 'mean_switches_per_episode': 1002.6666666666666, 'mean_arrived_vehicles_per_episode': 1461.6666666666667, 'mean_waiting_time': 4.696543347304373, 'mean_total_time_loss': 609.2268017526764, 'mean_vehicle_count': 29.855555555555554}

# %%
'''
SEARCH_SPACE = [
    # actor_lr, critic_lr, entropy_coef

    (1e-4, 3e-4, 0.03),
    (1e-4, 3e-4, 0.05),
    (1e-4, 3e-4, 0.07),

    (3e-4, 5e-4, 0.03),
    (3e-4, 5e-4, 0.05),
    (3e-4, 5e-4, 0.07),

    (5e-4, 1e-3, 0.03),
    (5e-4, 1e-3, 0.05),
    (5e-4, 1e-3, 0.07),
]

results = []

for run_id, (
    actor_lr,
    critic_lr,
    entropy_coef,
) in enumerate(
    SEARCH_SPACE,
    start=1,
):

    print(
        f"\n===== RUN {run_id}/{len(SEARCH_SPACE)} ====="
    )

    print(
        f"actor_lr={actor_lr} "
        f"critic_lr={critic_lr} "
        f"entropy_coef={entropy_coef}"
    )

    model, history, model_path = (
        train_graph_ctde(
            config_file=paths.config_file,
            network_file=paths.network_file,
            traffic_light_ids=traffic_light_ids,
            output_dir=OUTPUT_DIR,
            total_timesteps=20_000,
            rollout_steps=126,
            actor_learning_rate=actor_lr,
            critic_learning_rate=critic_lr,
            entropy_coef=entropy_coef,
            env_kwargs={
                "green_phase_count": GREEN_PHASE_COUNT,
                "min_green_seconds": MIN_GREEN_SECONDS,
                "seconds_per_action": SECONDS_PER_ACTION,
                "switch_penalty": SWITCH_PENALTY,
                "global_metric_interval": 10,
            },
        )
    )

    evaluation = evaluate_policy(
        model=model,
        config_file=paths.config_file,
        network_file=paths.network_file,
        traffic_light_ids=traffic_light_ids,
        episodes=3,
        max_steps=EPISODE_STEPS,
    )

    results.append({
        "actor_lr": actor_lr,
        "critic_lr": critic_lr,
        "entropy_coef": entropy_coef,
        "reward": evaluation["mean_total_reward"],
        "waiting_time": evaluation["mean_waiting_time"],
        "arrived": evaluation["mean_arrived_vehicles_per_episode"],
        "switches": evaluation["mean_switches_per_episode"],
    })

    df = pd.DataFrame(results)

    df = df.sort_values(
        "reward",
        ascending=False,
    )

    clear_output(wait=True)

    print(
        "\n===== CURRENT LEADERBOARD =====\n"
    )

    display(df)

    plt.figure(
        figsize=(12, 5)
    )

    labels = [
        (
            f"A={r['actor_lr']}\n"
            f"C={r['critic_lr']}\n"
            f"E={r['entropy_coef']}"
        )
        for r in results
    ]

    rewards = [
        r["reward"]
        for r in results
    ]

    plt.bar(
        range(len(rewards)),
        rewards,
    )

    plt.xticks(
        range(len(labels)),
        labels,
        rotation=45,
        ha="right",
    )

    plt.ylabel(
        "Mean Evaluation Reward"
    )

    plt.title(
        "Hyperparameter Search"
    )

    plt.tight_layout()

    plt.show()

df = pd.DataFrame(results)

df = df.sort_values(
    "reward",
    ascending=False,
)

print("\n===== FINAL RESULTS =====\n")

display(df)

df.to_csv(
    "hyperparameter_search_results.csv",
    index=False,
)

print(
    "\nSaved: hyperparameter_search_results.csv"
)'''
# Out:
# '\nSEARCH_SPACE = [\n    # actor_lr, critic_lr, entropy_coef\n\n    (1e-4, 3e-4, 0.03),\n    (1e-4, 3e-4, 0.05),\n    (1e-4, 3e-4, 0.07),\n\n    (3e-4, 5e-4, 0.03),\n    (3e-4, 5e-4, 0.05),\n    (3e-4, 5e-4, 0.07),\n\n    (5e-4, 1e-3, 0.03),\n    (5e-4, 1e-3, 0.05),\n    (5e-4, 1e-3, 0.07),\n]\n\nresults = []\n\nfor run_id, (\n    actor_lr,\n    critic_lr,\n    entropy_coef,\n) in enumerate(\n    SEARCH_SPACE,\n    start=1,\n):\n\n    print(\n        f"\n===== RUN {run_id}/{len(SEARCH_SPACE)} ====="\n    )\n\n    print(\n        f"actor_lr={actor_lr} "\n        f"critic_lr={critic_lr} "\n        f"entropy_coef={entropy_coef}"\n    )\n\n    model, history, model_path = (\n        train_graph_ctde(\n            config_file=paths.config_file,\n            network_file=paths.network_file,\n            traffic_light_ids=traffic_light_ids,\n            output_dir=OUTPUT_DIR,\n            total_timesteps=20_000,\n            rollout_steps=126,\n            actor_learning_rate=actor_lr,\n            critic_learning_rate=critic_lr,\n            entropy_coef=entropy_coef,\n            env_kwargs={\n                "green_phase_count": GREEN_PHASE_COUNT,\n                "min_green_seconds": MIN_GREEN_SECONDS,\n                "seconds_per_action": SECONDS_PER_ACTION,\n                "switch_penalty": SWITCH_PENALTY,\n                "global_metric_interval": 10,\n            },\n        )\n    )\n\n    evaluation = evaluate_policy(\n        model=model,\n        config_file=paths.config_file,\n        network_file=paths.network_file,\n        traffic_light_ids=traffic_light_ids,\n        episodes=3,\n        max_steps=EPISODE_STEPS,\n    )\n\n    results.append({\n        "actor_lr": actor_lr,\n        "critic_lr": critic_lr,\n        "entropy_coef": entropy_coef,\n        "reward": evaluation["mean_total_reward"],\n        "waiting_time": evaluation["mean_waiting_time"],\n        "arrived": evaluation["mean_arrived_vehicles_per_episode"],\n        "switches": evaluation["mean_switches_per_episode"],\n    })\n\n    df = pd.DataFrame(results)\n\n    df = df.sort_values(\n        "reward",\n        ascending=False,\n    )\n\n    clear_output(wait=True)\n\n    print(\n        "\n===== CURRENT LEADERBOARD =====\n"\n    )\n\n    display(df)\n\n    plt.figure(\n        figsize=(12, 5)\n    )\n\n    labels = [\n        (\n            f"A={r[\'actor_lr\']}\n"\n            f"C={r[\'critic_lr\']}\n"\n            f"E={r[\'entropy_coef\']}"\n        )\n        for r in results\n    ]\n\n    rewards = [\n        r["reward"]\n        for r in results\n    ]\n\n    plt.bar(\n        range(len(rewards)),\n        rewards,\n    )\n\n    plt.xticks(\n        range(len(labels)),\n        labels,\n        rotation=45,\n        ha="right",\n    )\n\n    plt.ylabel(\n        "Mean Evaluation Reward"\n    )\n\n    plt.title(\n        "Hyperparameter Search"\n    )\n\n    plt.tight_layout()\n\n    plt.show()\n\ndf = pd.DataFrame(results)\n\ndf = df.sort_values(\n    "reward",\n    ascending=False,\n)\n\nprint("\n===== FINAL RESULTS =====\n")\n\ndisplay(df)\n\ndf.to_csv(\n    "hyperparameter_search_results.csv",\n    index=False,\n)\n\nprint(\n    "\nSaved: hyperparameter_search_results.csv"\n)'

# %% [markdown]
# # Git stuff

# %%
# !git status
# Out:
# On branch zak_new
# Your branch is up to date with 'origin/zak_new'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   src/marl_tsc/graph_based/train_graph_mappo.py

# %%
# !git add .

# %%
import shlex
commit_msg = '''
- Fixed graph_mappo env.close() bug. Now closes after training
'''

'''
TODO:
- Heterogenous networks
- Full Training run on bigger networks
- Possible integration with Andy's updated code
- Possible integration with Tom's networks
'''
# Out:
# "\nTODO:\n- Heterogenous networks\n- Full Training run on bigger networks\n- Possible integration with Andy's updated code\n- Possible integration with Tom's networks\n"

# %%
print(commit_msg)
# Out:
# - Fixed graph_mappo env.close() bug. Now closes after training

# %%
# !git config --global user.email "zakfayle@gmail.com"
# !git config --global user.name "IsaacFayle-Waters"
# !git commit -m {shlex.quote(commit_msg)}
# Out:
# [zak_new 857343c] - Fixed graph_mappo env.close() bug. Now closes after training
#  1 file changed, 49 insertions(+), 46 deletions(-)

# %%
# !git push origin zak_new
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 774 bytes | 774.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/abergh18/marl-tsc.git
#    dda7ed6..857343c  zak_new -> zak_new

# %%
# 2. Fetch the latest main branch commit from GitHub
# !git fetch origin main

# 3. Create a temporary branch based exactly on GitHub's main commit (FETCH_HEAD)
# !git checkout -b temp_merge_branch FETCH_HEAD

# 4. Pull ONLY the graph_based directory from your local zak_new branch
# !git checkout zak_new -- src/marl_tsc/graph_based/

# 5. Commit just this directory addition
# !git commit -m "Integrate graph_based directory into main branch"

# 6. Push this clean temporary branch directly into GitHub's main branch
# !git push https://IsaacFayle-Waters:{token}@github.com/abergh18/marl-tsc.git temp_merge_branch:main

# 7. Switch back to your zak_new branch so your workspace is back to normal
# !git checkout zak_new
# !git branch -D temp_merge_branch
# Out:
# From https://github.com/abergh18/marl-tsc
#  * branch            main       -> FETCH_HEAD
# Switched to a new branch 'temp_merge_branch'
# [temp_merge_branch 18d7368] Integrate graph_based directory into main branch
#  20 files changed, 3301 insertions(+)
#  create mode 100644 src/marl_tsc/graph_based/Graph_Based.md
#  create mode 100644 src/marl_tsc/graph_based/advantage_estimator.py
#  create mode 100644 src/marl_tsc/graph_based/base_trainer.py
#  create mode 100644 src/marl_tsc/graph_based/encoders/base_encoder.py
#  create mode 100644 src/marl_tsc/graph_based/encoders/gat_encoder.py
#  create mode 100644 src/marl_tsc/graph_based/graph_builder.py
#  create mode 100644 src/marl_tsc/graph_based/graph_ctde_trainer.py
#  create mode 100644 src/marl_tsc/graph_based/graph_env.py
#  create mode 100644 src/marl_tsc/graph_based/graph_mappo_trainer.py
#  create mode 100644 src/marl_tsc/graph_based/graph_policy_adapter.py
#  create mode 100644 src/marl_tsc/graph_based/graph_rollout.py
#  create mode 100644 src/marl_tsc/graph_based/graph_runner.py
#  create mode 100644 src/marl_tsc/graph_based/graph_types.py
#  create mode 100644 src/marl_tsc/graph_based/models/actor.py
#  create mode 100644 src/marl_tsc/graph_based/models/critic.py
#  create mode 100644 src/marl_tsc/graph_based/models/graph_policy.py
#  create mode 100644 src/marl_tsc/graph_based/models/policy_factory.py
#  create mode 100644 src/marl_tsc/graph_based/run_training.py
#  create mode 100644 src/marl_tsc/graph_based/train_graph_ctde.py
#  create mode 100644 src/marl_tsc/graph_based/train_graph_mappo.py
# Enumerating objects: 30, done.
# Counting objects: 100% (30/30), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (26/26), done.
# Writing objects: 100% (27/27), 23.74 KiB | 11.87 MiB/s, done.
# Total 27 (delta 2), reused 10 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/abergh18/marl-tsc.git
#    9d16c5b..18d7368  temp_merge_branch -> main
# Switched to branch 'zak_new'
# Your branch is up to date with 'origin/zak_new'.
# Deleted branch temp_merge_branch (was 18d7368).
