# %%
# #Uncomment these in a fresh notebook environment.
# %cd /content/marl-tsc
# %pip install -r requirements.txt
# %pip install -e .

# %%
#GITHUB --> COLAB CLONE / env setup
import os

# Turn on libsumo for this specific script
os.environ["USE_LIBSUMO"] = "1"

from google.colab import userdata

# 1. Get your access token
token = userdata.get('GH_TOKEN')

# 2. Clone the repo if it's not already there
repo_path = '/content/marl-tsc'
if not os.path.exists(repo_path):
    # !git clone --branch main --single-branch https://{token}@github.com/abergh18/marl-tsc.git

# 3. CRUCIAL: Move to the root directory
# This ensures that 'import models' or 'import utils' works correctly
# %cd {repo_path}


# 4. Install dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'marl-tsc'...
# remote: Enumerating objects: 1107, done.
# remote: Counting objects: 100% (342/342), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 1107 (delta 240), reused 137 (delta 133), pack-reused 765 (from 1)
# Receiving objects: 100% (1107/1107), 5.60 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (602/602), done.
# /content/marl-tsc
# Collecting pettingzoo==1.26.1 (from -r requirements.txt (line 1))
#   Downloading pettingzoo-1.26.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting gymnasium==1.2.3 (from -r requirements.txt (line 2))
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy<2.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.0.2)
# Collecting traci==1.26.0 (from -r requirements.txt (line 4))
#   Downloading traci-1.26.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting sumolib==1.26.0 (from -r requirements.txt (line 5))
#   Downloading sumolib-1.26.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting jupyter==1.1.1 (from -r requirements.txt (line 6))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib<3.11,>=3.9 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Collecting supersuit==3.10.0 (from -r requirements.txt (line 8))
#   Downloading supersuit-3.10.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting stable-baselines3==2.8.0 (from -r requirements.txt (line 9))
#   Downloading stable_baselines3-2.8.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: torch==2.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.11.0+cu128)
# Collecting torch-geometric==2.8.0 (from -r requirements.txt (line 11))
#   Downloading torch_geometric-2.8.0-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==1.2.3->-r requirements.txt (line 2)) (0.0.6)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.6.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (7.17.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter==1.1.1->-r requirements.txt (line 6)) (7.7.1)
# Collecting jupyterlab (from jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading jupyterlab-4.6.2-py3-none-any.whl.metadata (16 kB)
# Collecting tinyscaler>=1.2.6 (from supersuit==3.10.0->-r requirements.txt (line 8))
#   Downloading tinyscaler-1.2.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.29.7)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.11.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.14.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.8.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch==2.11.0->-r requirements.txt (line 10)) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch==2.11.0->-r requirements.txt (line 10)) (1.5.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.9->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.11.0->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric==2.8.0->-r requirements.txt (line 11)) (1.24.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (6.5.7)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.11.0->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (5.9.1)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (2.20.0)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.28.1)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading jupyter_builder-1.1.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.20.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (3.3.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.25.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.8.0->-r requirements.txt (line 9)) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric==2.8.0->-r requirements.txt (line 11)) (2026.6.17)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.16.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (4.10.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6))
#   Downloading json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.26.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (2.21.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.1.1->-r requirements.txt (line 6)) (0.8.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1->-r requirements.txt (line 6)) (2.8.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.1->-r requirements.txt (line 6)) (0.8.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1->-r requirements.txt (line 6)) (3.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab->jupyter==1.1.1->-r requirements.txt (line 6)) (1.4.0)
# Downloading pettingzoo-1.26.1-py3-none-any.whl (805 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.5/805.5 kB 61.7 MB/s eta 0:00:00
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 72.0 MB/s eta 0:00:00
# Downloading traci-1.26.0-py2.py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.4/138.4 kB 18.0 MB/s eta 0:00:00
# Downloading sumolib-1.26.0-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 28.6 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading supersuit-3.10.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.5 MB/s eta 0:00:00
# Downloading stable_baselines3-2.8.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 23.2 MB/s eta 0:00:00
# Downloading torch_geometric-2.8.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.2 MB/s eta 0:00:00
# Downloading tinyscaler-1.2.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (563 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.6/563.6 kB 54.2 MB/s eta 0:00:00
# Downloading jupyterlab-4.6.2-py3-none-any.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 133.0 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading jupyter_builder-1.1.1-py3-none-any.whl (913 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.3/913.3 kB 70.4 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 10.4 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 8.2 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 140.2 MB/s eta 0:00:00
# Downloading json5-0.15.0-py3-none-any.whl (36 kB)
# Installing collected packages: sumolib, traci, tinyscaler, json5, jedi, gymnasium, async-lru, supersuit, pettingzoo, jupyter-builder, torch-geometric, stable-baselines3, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.3.0
#     Uninstalling gymnasium-1.3.0:
#       Successfully uninstalled gymnasium-1.3.0
# Successfully installed async-lru-2.3.0 gymnasium-1.2.3 jedi-0.20.0 json5-0.15.0 jupyter-1.1.1 jupyter-builder-1.1.1 jupyter-lsp-2.3.1 jupyterlab-4.6.2 jupyterlab-server-2.28.0 pettingzoo-1.26.1 stable-baselines3-2.8.0 sumolib-1.26.0 supersuit-3.10.0 tinyscaler-1.2.8 torch-geometric-2.8.0 traci-1.26.0

# %%
# !pip install eclipse-sumo libsumo
# For simulation
# !apt-get install -y xvfb
# !pip install pyvirtualdisplay

import os
os.environ["SUMO_HOME"] = "/usr/local/lib/python3.12/dist-packages/sumo"
os.environ["PATH"] += ":/usr/local/lib/python3.12/dist-packages/sumo/bin"
# Out:
# Collecting eclipse-sumo
#   Downloading eclipse_sumo-1.27.1-py3-none-manylinux_2_28_x86_64.whl.metadata (6.4 kB)
# Collecting libsumo
#   Downloading libsumo-1.27.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting sumo-data>=1.27.1 (from eclipse-sumo)
#   Downloading sumo_data-1.27.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting traci>=1.27.1 (from libsumo)
#   Downloading traci-1.27.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting sumolib>=1.27.1 (from traci>=1.27.1->libsumo)
#   Downloading sumolib-1.27.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading eclipse_sumo-1.27.1-py3-none-manylinux_2_28_x86_64.whl (147.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.1/147.1 MB 17.1 MB/s eta 0:00:00
# Downloading libsumo-1.27.1-cp312-cp312-manylinux_2_28_x86_64.whl (85.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 MB 29.1 MB/s eta 0:00:00
# Downloading sumo_data-1.27.1-py3-none-any.whl (16.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 97.8 MB/s eta 0:00:00
# Downloading traci-1.27.1-py2.py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 14.9 MB/s eta 0:00:00
# Downloading sumolib-1.27.1-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.2/236.2 kB 20.1 MB/s eta 0:00:00
# Installing collected packages: sumolib, sumo-data, traci, eclipse-sumo, libsumo
#   Attempting uninstall: sumolib
#     Found existing installation: sumolib 1.26.0
#     Uninstalling sumolib-1.26.0:
#       Successfully uninstalled sumolib-1.26.0
#   Attempting uninstall: traci
#     Found existing installation: traci 1.26.0
#     Uninstalling traci-1.26.0:
#       Successfully uninstalled traci-1.26.0
# Successfully installed eclipse-sumo-1.27.1 libsumo-1.27.1 sumo-data-1.27.1 sumolib-1.27.1 traci-1.27.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 53 not upgraded.
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
from pathlib import Path
import sys
#Had to remove '.parent' for colab specific version
PROJECT_ROOT = Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import traci
import sys

def print_comparison_table(rows):
  columns = [
        "Policy",
        "Episodes",
        "Mean total reward",
        "Mean local queue",
        "Mean max queue",
        "Mean waiting time",
        "Mean total time loss",
        "Total completed steps",
        "Mean switches / episode",
    ]

  def format_value(value):
        if isinstance(value, float):
            return f"{value:.3f}"
        return str(value)

  widths = {column: len(column) for column in columns}
  for row in rows:
      for column in columns:
          widths[column] = max(widths[column], len(format_value(row.get(column, ""))))

  header = " | ".join(column.ljust(widths[column]) for column in columns)
  separator = "-+-".join("-" * widths[column] for column in columns)
  print(header)
  print(separator)
  for row in rows:
      print(" | ".join(format_value(row.get(column, "")).ljust(widths[column]) for column in columns))

def reset_traci_connection():
    # Force clear TraCI's internal connection registries
    try:
        traci.switch("default")
        traci.close()
    except Exception:
        pass # No active connection to close

    try:
        # Completely purge the connection dictionary tracking connections
        if 'traci.main' in sys.modules:
            traci.main._connections.clear()
            print("Purged TraCI connections dictionary.")
    except Exception:
        pass

    # Reset the module completely out of Python sys memory
    if 'traci' in sys.modules:
        del sys.modules['traci']
        # Re-import fresh only if needed by subsequent code, otherwise it's handled by SumoTrafficEnv
    # print("TraCI state successfully reset!")

# %%
from marl_tsc.simulation_generator import SimulationGenerator
from marl_tsc.training import train_ppo, evaluate_policy, plot_training_histories
from marl_tsc.mappo import train_mappo
from marl_tsc.baselines import random_actions, fixed_time_actions


NOTEBOOK_DIR = Path.cwd().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent if (NOTEBOOK_DIR / "main_flow.ipynb").exists() else NOTEBOOK_DIR
OUTPUT_DIR = PROJECT_ROOT / "outputs"

# %% [markdown]
# ## 1. Generate the SUMO simulation files

# %%
import shutil
from pathlib import Path
import os
import sys
import site

site_packages = site.getsitepackages()[0]
sumo_path = Path(site_packages) / "sumo"

if not (sumo_path / "tools" / "randomTrips.py").exists():
    import sumo
    sumo_path = Path(sumo.__file__).parent

os.environ["SUMO_HOME"] = str(sumo_path)
os.environ["PATH"] += f":{sumo_path}/bin"
print(f"SUMO_HOME set to: {os.environ['SUMO_HOME']}")

# ==========================================
# MASTER VARIABLE: Controls the entire run
# ==========================================
EPISODE_STEPS = 1000
SECONDS_PER_ACTION = 5
SIMULATION_DURATION = EPISODE_STEPS * SECONDS_PER_ACTION
TRAFFIC_SPAWN_DURATION = SIMULATION_DURATION
NUM_EPISODES = 30
EVALUATION_EPISODES = 5
TOTAL_TIMESTEPS = 300000
MIN_GREEN_SECONDS = 10

# ==========================================
# Network Configuration — change these to swap cities
# ==========================================
NETWORK_ONE_FILE = "lancasterv2.net.xml"
NETWORK_TWO_FILE = "york_cleaned.net.xml"

# ==========================================
# Output directories
# ==========================================
OUTPUT_DIR_ONE = PROJECT_ROOT / "outputs_network_one"
OUTPUT_DIR_TWO = PROJECT_ROOT / "outputs_network_two"
OUTPUT_DIR_ONE.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR_TWO.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR = OUTPUT_DIR_ONE

vtypes_content = """<additional>
    <vType id="car"    vClass="passenger" speedFactor="normc(1,0.1,0.2,2)" length="4.5" maxSpeed="50"/>
    <vType id="van"    vClass="delivery"  speedFactor="normc(0.9,0.1,0.2,2)" length="6.0" maxSpeed="40"/>
    <vType id="bus"    vClass="bus"       speedFactor="normc(0.85,0.05,0.2,2)" length="12.0" maxSpeed="30"/>
</additional>"""

vtypes_one = OUTPUT_DIR_ONE / "vtypes.xml"
vtypes_one.write_text(vtypes_content)
vtypes_two = OUTPUT_DIR_TWO / "vtypes.xml"
vtypes_two.write_text(vtypes_content)

# ==========================================
# Network One
# ==========================================
net_one_path = OUTPUT_DIR_ONE / NETWORK_ONE_FILE
for p in [Path('/content') / NETWORK_ONE_FILE,
          Path('/content/marl-tsc') / NETWORK_ONE_FILE,
          net_one_path]:
    if p.exists():
        print(f"Found Network One at: {p}")
        if p.resolve() != net_one_path.resolve():
            shutil.copy2(p, net_one_path)
            print(f"Copied to {net_one_path}")
        break

generator_one = SimulationGenerator(
    output_dir=OUTPUT_DIR_ONE,
    network_filename=NETWORK_ONE_FILE,
    trip_fringe_factor=10,
    allow_fringe=True,
    trip_period=1,
    min_distance=50,
    vtypes_file=vtypes_one,
)
generator_one.generate_peak_trips(
    peak_end=int(SIMULATION_DURATION * 0.7)
)

generator_one.generate_config()
paths_one = generator_one.paths
tls_one = list(generator_one.traffic_light_ids)
print(f"Network One traffic lights ({len(tls_one)}): {tls_one}")

# ==========================================
# Network Two
# ==========================================
net_two_path = OUTPUT_DIR_TWO / NETWORK_TWO_FILE
for p in [Path('/content') / NETWORK_TWO_FILE,
          Path('/content/marl-tsc') / NETWORK_TWO_FILE,
          net_two_path]:
    if p.exists():
        print(f"Found Network Two at: {p}")
        if p.resolve() != net_two_path.resolve():
            shutil.copy2(p, net_two_path)
            print(f"Copied to {net_two_path}")
        break

generator_two = SimulationGenerator(
    output_dir=OUTPUT_DIR_TWO,
    network_filename=NETWORK_TWO_FILE,
    trip_fringe_factor=10,
    allow_fringe=True,
    trip_period=0.5,
    min_distance=50,
    vtypes_file=vtypes_two,
)
generator_two.generate_peak_trips(
    peak_end=int(SIMULATION_DURATION * 0.7)
)

generator_two.generate_config()
paths_two = generator_two.paths
tls_two = list(generator_two.traffic_light_ids)
print(f"Network Two traffic lights ({len(tls_two)}): {tls_two}")

# ==========================================
# Discover shared obs dimensions
# ==========================================
from marl_tsc.traffic_env import SumoTrafficEnv

reset_traci_connection()
env = SumoTrafficEnv(paths_one.config_file, possible_agents=tls_one, max_steps=10)
obs, _ = env.reset()
SHARED_MAX_LANES = env.max_lanes_per_tls
SHARED_GREEN_PHASES = env.green_phase_count
env.close()

reset_traci_connection()
env = SumoTrafficEnv(paths_two.config_file, possible_agents=tls_two, max_steps=10)
obs, _ = env.reset()
SHARED_MAX_LANES = max(SHARED_MAX_LANES, env.max_lanes_per_tls)
SHARED_GREEN_PHASES = max(SHARED_GREEN_PHASES, env.green_phase_count)
env.close()

print(f"Shared max_lanes_per_tls: {SHARED_MAX_LANES}")
print(f"Shared green_phase_count: {SHARED_GREEN_PHASES}")

TRAIN_ENV_KWARGS = {
    "min_green_seconds": MIN_GREEN_SECONDS,
    "max_lanes_per_tls": SHARED_MAX_LANES,
    "green_phase_count": SHARED_GREEN_PHASES,
}
EVAL_ENV_KWARGS = {
    "min_green_seconds": MIN_GREEN_SECONDS,
    "seconds_per_action": SECONDS_PER_ACTION,
    "switch_penalty": 0.0,
    "max_lanes_per_tls": SHARED_MAX_LANES,
    "green_phase_count": SHARED_GREEN_PHASES,
}

paths = paths_one
tls_in_net = tls_one
# Out:
# SUMO_HOME set to: /usr/local/lib/python3.12/dist-packages/sumo
# Found Network One at: /content/marl-tsc/lancasterv2.net.xml
# Copied to /content/marl-tsc/outputs_network_one/lancasterv2.net.xml
# Discovered 8 traffic lights: ['cluster_1395459938_3904465077_6288784963', 'joinedS_6528610881_cluster_1305014216_5464547754_6100910_6528610880_cluster_2217469_5464547745_5464547748_5464547749', 'joinedS_cluster_1670999797_1670999973_2217366_3903086088_#1more_cluster_1670999799_2217365_6308327', 'joinedS_3903073405_cluster_5835265011_610595547', 'cluster_1671362532_2217405_253943174_3904937313_#3more', 'cluster_1111602959_6308330_6398665769_6398666101', 'cluster_2217373_5464742560_610595545_6288784968_#6more', 'cluster_27212021_5464547758_6299153326']
# Network One traffic lights (8): ['cluster_1395459938_3904465077_6288784963', 'joinedS_6528610881_cluster_1305014216_5464547754_6100910_6528610880_cluster_2217469_5464547745_5464547748_5464547749', 'joinedS_cluster_1670999797_1670999973_2217366_3903086088_#1more_cluster_1670999799_2217365_6308327', 'joinedS_3903073405_cluster_5835265011_610595547', 'cluster_1671362532_2217405_253943174_3904937313_#3more', 'cluster_1111602959_6308330_6398665769_6398666101', 'cluster_2217373_5464742560_610595545_6288784968_#6more', 'cluster_27212021_5464547758_6299153326']
# Found Network Two at: /content/marl-tsc/york_cleaned.net.xml
# Copied to /content/marl-tsc/outputs_network_two/york_cleaned.net.xml
# Discovered 10 traffic lights: ['joinedS_1629111685_8236824230_8236824233_cluster_1629111693_1629111709_1629111723_27497547_#1more_#1more', 'cluster_27497557_280867238_9209477353_9209477354', '9188508158', 'joinedS_21268486_9146743323_cluster_1435273283_1435273297_1435273300_21268487_#1more', '1709832578', '9174145494', 'cluster_2320517021_2320517022_8236824244', 'joinedS_12728487_8233484841_8233484843_cluster_27231337_703830048_#1more', 'cluster_12728484_9209477371_9209477372', 'cluster_1430554973_316116508_8236824245']
# Network Two traffic lights (10): ['joinedS_1629111685_8236824230_8236824233_cluster_1629111693_1629111709_1629111723_27497547_#1more_#1more', 'cluster_27497557_280867238_9209477353_9209477354', '9188508158', 'joinedS_21268486_9146743323_cluster_1435273283_1435273297_1435273300_21268487_#1more', '1709832578', '9174145494', 'cluster_2320517021_2320517022_8236824244', 'joinedS_12728487_8233484841_8233484843_cluster_27231337_703830048_#1more', 'cluster_12728484_9209477371_9209477372', 'cluster_1430554973_316116508_8236824245']
# Warning! pyarrow is installed with version 18.1.0 which might be incompatible with libsumo which is compiled against libarrow2300.
#  Try to uninstall pyarrow or install a matching pyarrow version, if you encounter problems.
# Shared max_lanes_per_tls: 9
# Shared green_phase_count: 4

# %%
import xml.etree.ElementTree as ET

for name, path in [("Network One", OUTPUT_DIR_ONE), ("Network Two", OUTPUT_DIR_TWO)]:
    tree = ET.parse(str(path / "routes.rou.xml"))
    root = tree.getroot()
    vehicles = root.findall("vehicle")
    if vehicles:
        departs = [float(v.get("depart", 0)) for v in vehicles]
        print(f"{name}: {len(vehicles)} vehicles | depart range: {min(departs):.0f}s - {max(departs):.0f}s | avg gap: {(max(departs)-min(departs))/len(vehicles):.2f}s")
# Out:
# Network One: 1750 vehicles | depart range: 1s - 1748s | avg gap: 1.00s
# Network Two: 3500 vehicles | depart range: 0s - 1748s | avg gap: 0.50s

# %% [markdown]
# ## 2. Run the simple baselines
#
# Random and fixed-time are useful sanity checks before training. They use the same environment and the same evaluation seeds as the learned policies.

# %%
import traci
import sys

# ==========================================
# Network One Baselines
# ==========================================
reset_traci_connection()
random_one_result = evaluate_policy(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    policy=random_actions,
    episodes=1,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

reset_traci_connection()
fixed_one_result = evaluate_policy(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    policy=fixed_time_actions,
    episodes=1,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

# ==========================================
# Network Two Baselines
# ==========================================
reset_traci_connection()
random_two_result = evaluate_policy(
    config_file=paths_two.config_file,
    traffic_light_ids=tls_two,
    policy=random_actions,
    episodes=1,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

reset_traci_connection()
fixed_two_result = evaluate_policy(
    config_file=paths_two.config_file,
    traffic_light_ids=tls_two,
    policy=fixed_time_actions,
    episodes=1,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

print("Baselines complete.")
# Out:
# Finished Evaluation Episode 1/1 - Total Reward: -18163.74
# Finished Evaluation Episode 1/1 - Total Reward: -33359.19
# Finished Evaluation Episode 1/1 - Total Reward: -873.00
# Finished Evaluation Episode 1/1 - Total Reward: -6520.45
# Baselines complete.

# %% [markdown]
# ## 3. Train
#
#  MAPPO adds a centralized critic and a shared decentralized actor.

# %% [markdown]
# ### MAPPO

# %%
reset_traci_connection()
mappo_model, mappo_history, mappo_model_path = train_mappo(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    output_dir=OUTPUT_DIR_ONE,
    total_timesteps=TOTAL_TIMESTEPS,
    rollout_steps=1000,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=TRAIN_ENV_KWARGS,
    use_peer_reward=False,
)

fig, ax = plot_training_histories(mappo_history)
plt.show()
print("Saved MAPPO model:", mappo_model_path)
# Out:
# [MAPPO] Episode 1 | Return: -1365.20 | Total Steps: 500
# [MAPPO] Episode 2 | Return: -1318.64 | Total Steps: 1000
# [MAPPO] Episode 3 | Return: -1303.83 | Total Steps: 1500
# [MAPPO] Episode 4 | Return: -679.89 | Total Steps: 2000
# [MAPPO] Episode 5 | Return: -1281.08 | Total Steps: 2500
# [MAPPO] Episode 6 | Return: -1424.71 | Total Steps: 3000
# [MAPPO] Episode 7 | Return: -1336.07 | Total Steps: 3500
# [MAPPO] Episode 8 | Return: -1333.24 | Total Steps: 4000
# [MAPPO] Episode 9 | Return: -1426.05 | Total Steps: 4500
# [MAPPO] Episode 10 | Return: -1212.42 | Total Steps: 5000
# [MAPPO] Episode 11 | Return: -1384.01 | Total Steps: 5500
# [MAPPO] Episode 12 | Return: -1265.42 | Total Steps: 6000
# [MAPPO] Episode 13 | Return: -1378.74 | Total Steps: 6500
# [MAPPO] Episode 14 | Return: -1300.73 | Total Steps: 7000
# [MAPPO] Episode 15 | Return: -1360.12 | Total Steps: 7500
# [MAPPO] Episode 16 | Return: -1300.11 | Total Steps: 8000
# [MAPPO] Episode 17 | Return: -1253.20 | Total Steps: 8500
# [MAPPO] Episode 18 | Return: -1306.45 | Total Steps: 9000
# [MAPPO] Episode 19 | Return: -1152.25 | Total Steps: 9500
# [MAPPO] Episode 20 | Return: -1380.70 | Total Steps: 10000
# [MAPPO] Episode 21 | Return: -1338.19 | Total Steps: 10500
# [MAPPO] Episode 22 | Return: -1387.28 | Total Steps: 11000
# [MAPPO] Episode 23 | Return: -1317.05 | Total Steps: 11500
# [MAPPO] Episode 24 | Return: -1294.33 | Total Steps: 12000
# [MAPPO] Episode 25 | Return: -1413.64 | Total Steps: 12500
# [MAPPO] Episode 26 | Return: -1393.80 | Total Steps: 13000
# [MAPPO] Episode 27 | Return: -1342.55 | Total Steps: 13500
# [MAPPO] Episode 28 | Return: -1383.20 | Total Steps: 14000
# [MAPPO] Episode 29 | Return: -1334.92 | Total Steps: 14500
# [MAPPO] Episode 30 | Return: -1315.51 | Total Steps: 15000
# [MAPPO] Episode 31 | Return: -1179.77 | Total Steps: 15500
# [MAPPO] Episode 32 | Return: -1344.87 | Total Steps: 16000
# [MAPPO] Episode 33 | Return: -1310.56 | Total Steps: 16500
# [MAPPO] Episode 34 | Return: -1435.65 | Total Steps: 17000
# [MAPPO] Episode 35 | Return: -1346.01 | Total Steps: 17500
# [MAPPO] Episode 36 | Return: -1377.75 | Total Steps: 18000
# [MAPPO] Episode 37 | Return: -1467.22 | Total Steps: 18500
# [MAPPO] Episode 38 | Return: -1184.65 | Total Steps: 19000
# [MAPPO] Episode 39 | Return: -1389.24 | Total Steps: 19500
# [MAPPO] Episode 40 | Return: -1374.11 | Total Steps: 20000
# Saved MAPPO model: /content/marl-tsc/outputs_network_one/models/mappo.pt

# %%
reset_traci_connection()
gifting_mappo_model, gifting_mappo_history, gifting_mappo_model_path = train_mappo(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    output_dir=OUTPUT_DIR_ONE,
    total_timesteps=TOTAL_TIMESTEPS,
    rollout_steps=1000,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=TRAIN_ENV_KWARGS,
    use_peer_reward=True,
)

fig, ax = plot_training_histories(gifting_mappo_history)
plt.show()
print("Saved Gifting MAPPO model:", gifting_mappo_model_path)
# Out:
# [MAPPO] Episode 1 | Return: -1049.71 | Total Steps: 500
# [MAPPO] Episode 2 | Return: -1134.66 | Total Steps: 1000
# [MAPPO] Episode 3 | Return: -1151.89 | Total Steps: 1500
# [MAPPO] Episode 4 | Return: -1165.85 | Total Steps: 2000
# [MAPPO] Episode 5 | Return: -1085.78 | Total Steps: 2500
# [MAPPO] Episode 6 | Return: -972.17 | Total Steps: 3000
# [MAPPO] Episode 7 | Return: -1203.88 | Total Steps: 3500
# [MAPPO] Episode 8 | Return: -1058.04 | Total Steps: 4000
# [MAPPO] Episode 9 | Return: -1188.11 | Total Steps: 4500
# [MAPPO] Episode 10 | Return: -1123.30 | Total Steps: 5000
# [MAPPO] Episode 11 | Return: -982.75 | Total Steps: 5500
# [MAPPO] Episode 12 | Return: -1108.99 | Total Steps: 6000
# [MAPPO] Episode 13 | Return: -1014.80 | Total Steps: 6500
# [MAPPO] Episode 14 | Return: -1129.87 | Total Steps: 7000
# [MAPPO] Episode 15 | Return: -1008.95 | Total Steps: 7500
# [MAPPO] Episode 16 | Return: -1117.19 | Total Steps: 8000
# [MAPPO] Episode 17 | Return: -1100.47 | Total Steps: 8500
# [MAPPO] Episode 18 | Return: -1189.58 | Total Steps: 9000
# [MAPPO] Episode 19 | Return: -1088.81 | Total Steps: 9500
# [MAPPO] Episode 20 | Return: -1168.58 | Total Steps: 10000
# [MAPPO] Episode 21 | Return: -1161.96 | Total Steps: 10500
# [MAPPO] Episode 22 | Return: -1163.23 | Total Steps: 11000
# [MAPPO] Episode 23 | Return: -1223.10 | Total Steps: 11500
# [MAPPO] Episode 24 | Return: -1110.58 | Total Steps: 12000
# [MAPPO] Episode 25 | Return: -1192.40 | Total Steps: 12500
# [MAPPO] Episode 26 | Return: -1186.68 | Total Steps: 13000
# [MAPPO] Episode 27 | Return: -1185.00 | Total Steps: 13500
# [MAPPO] Episode 28 | Return: -1191.68 | Total Steps: 14000
# [MAPPO] Episode 29 | Return: -1052.14 | Total Steps: 14500
# [MAPPO] Episode 30 | Return: -1065.89 | Total Steps: 15000
# [MAPPO] Episode 31 | Return: -1184.35 | Total Steps: 15500
# [MAPPO] Episode 32 | Return: -1076.03 | Total Steps: 16000
# [MAPPO] Episode 33 | Return: -1256.20 | Total Steps: 16500
# [MAPPO] Episode 34 | Return: -1221.84 | Total Steps: 17000
# [MAPPO] Episode 35 | Return: -1140.25 | Total Steps: 17500
# [MAPPO] Episode 36 | Return: -1076.29 | Total Steps: 18000
# [MAPPO] Episode 37 | Return: -1236.75 | Total Steps: 18500
# [MAPPO] Episode 38 | Return: -989.98 | Total Steps: 19000
# [MAPPO] Episode 39 | Return: -1233.05 | Total Steps: 19500
# [MAPPO] Episode 40 | Return: -1268.07 | Total Steps: 20000
# Saved Gifting MAPPO model: /content/marl-tsc/outputs_network_one/models/mappo_peer_reward.pt

# %%
plt.close("all")

fig, ax = plt.subplots(figsize=(10, 5))

for label, history in [("MAPPO", mappo_history), ("Gifting MAPPO", gifting_mappo_history)]:
    if not history:
        continue
    timesteps = [h["timestep"] for h in history]
    returns = [h["moving_avg_episode_return"] for h in history]
    ax.plot(timesteps, returns, label=label)

ax.set_xlabel("Timesteps")
ax.set_ylabel("Moving Avg Episode Return")
ax.set_title("MAPPO vs Gifting MAPPO — Convergence")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Evaluate all policies on the same seeds
#
# The final comparison table keeps the baseline runs and adds the MAPPO policies on the same evaluation seeds.

# %%
# ==========================================
# Network One Evaluation (training network)
# ==========================================
reset_traci_connection()
mappo_one_result = evaluate_policy(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    policy=mappo_model,
    episodes=EVALUATION_EPISODES,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

reset_traci_connection()
gifting_mappo_one_result = evaluate_policy(
    config_file=paths_one.config_file,
    traffic_light_ids=tls_one,
    policy=gifting_mappo_model,
    episodes=EVALUATION_EPISODES,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)


# ==========================================
# Network Two Evaluation
# ==========================================
reset_traci_connection()
mappo_two_result = evaluate_policy(
    config_file=paths_two.config_file,
    traffic_light_ids=tls_two,
    policy=mappo_model,
    episodes=EVALUATION_EPISODES,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)

reset_traci_connection()
gifting_mappo_two_result = evaluate_policy(
    config_file=paths_two.config_file,
    traffic_light_ids=tls_two,
    policy=gifting_mappo_model,
    episodes=EVALUATION_EPISODES,
    max_steps=EPISODE_STEPS,
    seed=42,
    env_kwargs=EVAL_ENV_KWARGS,
)
# Out:
# Finished Evaluation Episode 1/5 - Total Reward: -24788.61
# Finished Evaluation Episode 2/5 - Total Reward: -27107.56
# Finished Evaluation Episode 3/5 - Total Reward: -30683.37
# Finished Evaluation Episode 4/5 - Total Reward: -27782.62
# Finished Evaluation Episode 5/5 - Total Reward: -25172.30
# Finished Evaluation Episode 1/5 - Total Reward: -24788.61
# Finished Evaluation Episode 2/5 - Total Reward: -27107.56
# Finished Evaluation Episode 3/5 - Total Reward: -30683.37
# Finished Evaluation Episode 4/5 - Total Reward: -27782.62
# Finished Evaluation Episode 5/5 - Total Reward: -25172.30
# Finished Evaluation Episode 1/5 - Total Reward: -764.62
# Finished Evaluation Episode 2/5 - Total Reward: -833.35
# Finished Evaluation Episode 3/5 - Total Reward: -760.47
# Finished Evaluation Episode 4/5 - Total Reward: -818.80
# Finished Evaluation Episode 5/5 - Total Reward: -724.23
# Finished Evaluation Episode 1/5 - Total Reward: -764.62
# Finished Evaluation Episode 2/5 - Total Reward: -833.35
# Finished Evaluation Episode 3/5 - Total Reward: -760.47
# Finished Evaluation Episode 4/5 - Total Reward: -818.80
# Finished Evaluation Episode 5/5 - Total Reward: -724.23

# %%
def make_row(label, result):
    return {
        "Policy": label,
        "Episodes": result["episodes"],
        "Mean total reward": result["mean_total_reward"],
        "Reward per step": round(result["mean_total_reward"] / result["total_completed_steps"], 4),
        "Mean local queue": result["mean_local_queue"],
        "Mean max queue": result["mean_max_queue"],
        "Mean waiting time": result["mean_waiting_time"],
        "Mean total time loss": result["mean_total_time_loss"],
        "Time loss per vehicle": round(result["mean_total_time_loss"] / max(result["mean_vehicle_count"], 1), 2),
        "Arrived vehicles": result["mean_arrived_vehicles_per_episode"],
        "Total completed steps": result["total_completed_steps"],
        "Mean switches / episode": result["mean_switches_per_episode"],
    }

print("\n=== Network One Results (Training Network) ===")
print_comparison_table([
    make_row("Random", random_one_result),
    make_row("Fixed-Time", fixed_one_result),
    make_row("MAPPO", mappo_one_result),
    make_row("Gifting MAPPO", gifting_mappo_one_result),
])

print("\n=== Network Two Results (Zero-Shot Transfer) ===")
print_comparison_table([
    make_row("Random", random_two_result),
    make_row("Fixed-Time", fixed_two_result),
    make_row("MAPPO", mappo_two_result),
    make_row("Gifting MAPPO", gifting_mappo_two_result),
])
# Out:
# === Network One Results (Training Network) ===
# Policy        | Episodes | Mean total reward | Mean local queue | Mean max queue | Mean waiting time | Mean total time loss | Total completed steps | Mean switches / episode
# --------------+----------+-------------------+------------------+----------------+-------------------+----------------------+-----------------------+------------------------
# Random        | 1        | -18163.745        | 3.071            | 23.000         | 102.458           | 311774.733           | 500                   | 282.000
# Fixed-Time    | 1        | -33359.188        | 4.930            | 23.000         | 107.039           | 403360.541           | 500                   | 252.000
# MAPPO         | 5        | -27106.891        | 4.102            | 23.000         | 108.710           | 396832.468           | 2500                  | 269.400
# Gifting MAPPO | 5        | -27106.891        | 4.102            | 23.000         | 108.710           | 396832.468           | 2500                  | 269.400
#
# === Network Two Results (Zero-Shot Transfer) ===
# Policy        | Episodes | Mean total reward | Mean local queue | Mean max queue | Mean waiting time | Mean total time loss | Total completed steps | Mean switches / episode
# --------------+----------+-------------------+------------------+----------------+-------------------+----------------------+-----------------------+------------------------
# Random        | 1        | -873.000          | 0.193            | 9.000          | 81.857            | 180724.084           | 500                   | 144.000
# Fixed-Time    | 1        | -6520.450         | 0.616            | 13.000         | 89.947            | 233228.640           | 500                   | 126.000
# MAPPO         | 5        | -780.293          | 0.175            | 7.000          | 86.017            | 191859.338           | 2500                  | 136.600
# Gifting MAPPO | 5        | -780.293          | 0.175            | 7.000          | 86.017            | 191859.338           | 2500                  | 136.600

# %%
import subprocess

def clean_up_sumo_processes():
    """Forcefully terminate any stuck SUMO or TraCI background processes."""
    subprocess.run(["pkill", "-9", "sumo"], capture_output=True)
    subprocess.run(["pkill", "-9", "sumo-gui"], capture_output=True)


clean_up_sumo_processes()

# %%
import subprocess
from pathlib import Path

def save_sumo_trace(
    config_file,
    traffic_light_ids,
    policy,
    output_dir,
    max_steps=600,
    seed=42,
    filename="simulation_trace.xml",
):
    from marl_tsc.traffic_env import SumoTrafficEnv
    from marl_tsc.wrappers import MinimumGreenTimeWrapper, PeerRewardingWrapper

    output_dir = Path(output_dir)
    trace_path = output_dir / filename

    env = None
    try:
        # 1. Automatically grab the exact settings the model was trained with
        model_kwargs = getattr(policy, "config", {}).get("env_kwargs", {})

        # 2. Create the environment using those identical settings
        env = SumoTrafficEnv(
            config_file,
            possible_agents=traffic_light_ids,
            max_steps=max_steps,
            seed=seed,
            render_mode=None,
            **model_kwargs,
        )

        # 3. Apply the exact same wrappers we used for evaluation
        env = MinimumGreenTimeWrapper(env, min_green_steps=10)

        if hasattr(policy, "action_dims") and len(policy.action_dims) > 1:
            env = PeerRewardingWrapper(env, division=10)

        observations, infos = env.reset(seed=seed)

        for step in range(max_steps):
            # 4. Ask the policy for its action
            actions = policy.act(observations, infos=infos, deterministic=True)
            observations, rewards, _, truncations, infos = env.step(actions)

            # PettingZoo standard for checking if the episode is finished
            if all(truncations.values()):
                break

    finally:
        if env is not None:
            env.close()

    print(f"Trace saved to: {trace_path}")
    return trace_path

# %%
reset_traci_connection()

save_sumo_trace(
    config_file=paths.config_file,
    traffic_light_ids=tls_in_net,
    policy=mappo_model,
    output_dir=OUTPUT_DIR,
    max_steps=600,
    seed=42,
)
# Out:
# Trace saved to: /content/marl-tsc/outputs_network_one/simulation_trace.xml
# PosixPath('/content/marl-tsc/outputs_network_one/simulation_trace.xml')

# %% [markdown]
# ### Traci Escape Hatch

# %%
on = True
if on:
    # Stop Traci processes if not already stopped, to prevent connection issues in subsequent runs
    import sys

    # 1. Force clear TraCI's internal connection registries
    try:
        import traci
        traci.switch("default")
        traci.close()
    except Exception:
        pass

    try:
        # Completely purge the connection dictionary tracking connections
        import traci.main
        traci.main._connections.clear()
        print("Purged TraCI connections dictionary.")
    except Exception:
        pass

    # 2. Reset the module completely out of Python sys memory
    if 'traci' in sys.modules:
        del sys.modules['traci']
        print("Flushed TraCI module from Python runtime memory.")

    # 3. Re-import fresh
    import traci
    print("TraCI state successfully reset!")
# Out:
# Flushed TraCI module from Python runtime memory.
# TraCI state successfully reset!

# %%
# Auto disconnects when run has done
from google.colab import runtime
runtime.unassign()
